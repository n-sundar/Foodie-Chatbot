# %%
import requests
import json
import pandas as pd

# %%
base_url = "https://developers.zomato.com/api/v2.1/"
headers = {'Accept': 'application/json', 'user-key': '7c5b4cda151a68ab847143b592e4c232'}
r = (requests.get(base_url + "locations?query=" + str('600044') + "&count=" + str(5), headers=headers).content).decode("utf-8")
json.loads(r)
# Out:
# {'location_suggestions': [],
#  'status': 'success',
#  'has_more': 0,
#  'has_total': 0,
#  'user_has_addresses': True}

# %%
location_json = json.loads(r)
location_results = len(location_json['location_suggestions'])
lat=location_json["location_suggestions"][0]["latitude"]
lon=location_json["location_suggestions"][0]["longitude"]
city_id=location_json["location_suggestions"][0]["city_id"]
print(location_results,lat,lon,city_id)
# Out:
# 5 12.916519 79.1325 11330

# %%
cuisines_dict={'american': 1,'chinese': 25, 'north indian': 50, 'italian': 55, 'mexican': 73, 'south indian': 85, 'thai': 95}
cuisines = str(cuisines_dict['north indian'])

cuisines = "%2C".join(cuisines.split(","))
headers = {'Accept': 'application/json', 'user-key': '7c5b4cda151a68ab847143b592e4c232'}
r = (requests.get(base_url + "search?q=" + str('') + "&count=" + str(10) + "&lat=" + str(lat) + "&lon=" + str(lon) + "&cuisines=" + str(cuisines), headers=headers).content).decode("utf-8")

# %%
json.loads(r)
# Out:
# {'results_found': 92,
#  'results_start': 0,
#  'results_shown': 10,
#  'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1,
#       'takeaway': -1},
#      'res_id': 18740086,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '18740086',
#     'name': 'Saleem Punjabi Dhaba',
#     'url': 'https://www.zomato.com/vellore/saleem-punjabi-dhaba-1-katpadi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Opposite to VIT Main Gate, Katpadi, Vellore',
#      'locality': 'Katpadi',
#      'city': 'Vellore',
#      'city_id': 11330,
#      'latitude': '12.9677489709',
#      'longitude': '79.1559972614',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Katpadi, Vellore'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian',
#     'timings': '12 Noon to 10 PM',
#     'average_cost_for_two': 350,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['No Alcohol Available',
#      'Takeaway Available',
#      'Lunch',
#      'Dinner',
#      'Cash',
#      'Delivery',
#      'Digital Payments Accepted',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.8',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.8'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 6308},
#     'all_reviews_count': 32,
#     'photos_url': 'https://www.zomato.com/vellore/saleem-punjabi-dhaba-1-katpadi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 13,
#     'menu_url': 'https://www.zomato.com/vellore/saleem-punjabi-dhaba-1-katpadi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18740086',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/vellore/saleem-punjabi-dhaba-1-katpadi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9100800902, +91 7569186888',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Dhaba'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 18740031,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '18740031',
#     'name': 'Tara Maa Restaurant',
#     'url': 'https://www.zomato.com/vellore/tara-maa-restaurant-katpadi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'VIT Main Gate, Kangeyanallore Road, Katpadi, Vellore',
#      'locality': 'Katpadi',
#      'city': 'Vellore',
#      'city_id': 11330,
#      'latitude': '12.9670654603',
#      'longitude': '79.1567150876',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Katpadi, Vellore'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian',
#     'timings': '10:30 AM to 10 PM',
#     'average_cost_for_two': 200,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['No Alcohol Available',
#      'Cash',
#      'Lunch',
#      'Takeaway Available',
#      'Dinner',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.9',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.9'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 91},
#     'all_reviews_count': 24,
#     'photos_url': 'https://www.zomato.com/vellore/tara-maa-restaurant-katpadi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 24,
#     'menu_url': 'https://www.zomato.com/vellore/tara-maa-restaurant-katpadi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18740031',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/vellore/tara-maa-restaurant-katpadi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9655694838',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 18740028,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '18740028',
#     'name': 'Yaseen Dhaba',
#     'url': 'https://www.zomato.com/vellore/yaseen-dhaba-katpadi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'VIT Main Gate, Kangeyanallore Road, Katpadi, Vellore',
#      'locality': 'Katpadi',
#      'city': 'Vellore',
#      'city_id': 11330,
#      'latitude': '12.9670164514',
#      'longitude': '79.1566547379',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Katpadi, Vellore'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian',
#     'timings': '10 AM to 10:30 PM',
#     'average_cost_for_two': 300,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['No Alcohol Available',
#      'Takeaway Available',
#      'Dinner',
#      'Lunch',
#      'Cash',
#      'Delivery',
#      'Digital Payments Accepted',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.6',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.6'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 2298},
#     'all_reviews_count': 23,
#     'photos_url': 'https://www.zomato.com/vellore/yaseen-dhaba-katpadi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 3,
#     'menu_url': 'https://www.zomato.com/vellore/yaseen-dhaba-katpadi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18740028',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/vellore/yaseen-dhaba-katpadi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9597871506',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Dhaba'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 18899866,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '18899866',
#     'name': 'Rajshree Punjabi Dhaba',
#     'url': 'https://www.zomato.com/vellore/rajshree-punjabi-dhaba-katpadi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '14/1 Post Office Street, Opposite to Venus Theatre Krishna Nagar, Katpadi, Vellore',
#      'locality': 'Katpadi',
#      'city': 'Vellore',
#      'city_id': 11330,
#      'latitude': '12.9019796151',
#      'longitude': '79.1309548169',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Katpadi, Vellore'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian',
#     'timings': '11 AM to 3 PM, 6 PM to 10 PM',
#     'average_cost_for_two': 200,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Delivery',
#      'Lunch',
#      'Cash',
#      'Takeaway Available',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.8',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.8'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 2276},
#     'all_reviews_count': 11,
#     'photos_url': 'https://www.zomato.com/vellore/rajshree-punjabi-dhaba-katpadi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 2,
#     'menu_url': 'https://www.zomato.com/vellore/rajshree-punjabi-dhaba-katpadi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18899866',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/vellore/rajshree-punjabi-dhaba-katpadi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9941008001',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Dhaba'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 18740048,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '18740048',
#     'name': 'Saleem Punjabi Dhaba',
#     'url': 'https://www.zomato.com/vellore/saleem-punjabi-dhaba-katpadi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'VIT Main Gate, Kangeyanallore Road, Katpadi, Vellore',
#      'locality': 'Katpadi',
#      'city': 'Vellore',
#      'city_id': 11330,
#      'latitude': '12.9672758720',
#      'longitude': '79.1568059474',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Katpadi, Vellore'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian',
#     'timings': '',
#     'average_cost_for_two': 250,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Takeaway Available',
#      'Lunch',
#      'Dinner',
#      'No Alcohol Available',
#      'Cash',
#      'Delivery',
#      'Air Conditioned',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '4.0',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.0'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 186},
#     'all_reviews_count': 10,
#     'photos_url': 'https://www.zomato.com/vellore/saleem-punjabi-dhaba-katpadi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 5,
#     'menu_url': 'https://www.zomato.com/vellore/saleem-punjabi-dhaba-katpadi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18740048',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/vellore/saleem-punjabi-dhaba-katpadi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9894975698',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Dhaba'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 18995459,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '18995459',
#     'name': 'UBQ By Barbeque Nation',
#     'url': 'https://www.zomato.com/vellore/ubq-by-barbeque-nation-kosapet?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '16/1, Survey T.S. 316, 316/4B3, First Floor, Officer Line, Kosapet, Vellore',
#      'locality': 'Kosapet',
#      'city': 'Vellore',
#      'city_id': 11330,
#      'latitude': '12.9089295000',
#      'longitude': '79.1317353000',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Kosapet, Vellore'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian, Biryani, Kebab, BBQ',
#     'timings': '10 AM to 9 PM',
#     'average_cost_for_two': 400,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Cash', 'Credit Card', 'Debit Card', 'Delivery'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/9/18995459/2d2b03b528e425b5250c2a4f0c6a27c3.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '3.5',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.5'},
#       'bg_color': {'type': 'lime', 'tint': '500'}},
#      'votes': 1096},
#     'all_reviews_count': 10,
#     'photos_url': 'https://www.zomato.com/vellore/ubq-by-barbeque-nation-kosapet/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 22,
#     'menu_url': 'https://www.zomato.com/vellore/ubq-by-barbeque-nation-kosapet/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/9/18995459/2d2b03b528e425b5250c2a4f0c6a27c3.jpg',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18995459',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/vellore/ubq-by-barbeque-nation-kosapet/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 8939880962, +91 8939805225',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': [],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 18739978,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '18739978',
#     'name': 'Punjabi Dhaba',
#     'url': 'https://www.zomato.com/vellore/punjabi-dhaba-katpadi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'VIT College, VIT Main Road, Katpadi, Vellore',
#      'locality': 'Katpadi',
#      'city': 'Vellore',
#      'city_id': 11330,
#      'latitude': '12.9675343122',
#      'longitude': '79.1573564708',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Katpadi, Vellore'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian',
#     'timings': '11:10am – 3:45pm, 6:15pm – 10pm (Mon-Sun)',
#     'average_cost_for_two': 300,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'No Alcohol Available',
#      'Takeaway Available',
#      'Cash',
#      'Delivery',
#      'Lunch',
#      'Pure Veg',
#      'Free Parking',
#      'Indoor Seating',
#      'Digital Payments Accepted'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.6',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.6'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 340},
#     'all_reviews_count': 8,
#     'photos_url': 'https://www.zomato.com/vellore/punjabi-dhaba-katpadi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 3,
#     'menu_url': 'https://www.zomato.com/vellore/punjabi-dhaba-katpadi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18739978',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/vellore/punjabi-dhaba-katpadi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9843064071',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 0, 'takeaway': -1},
#      'res_id': 19241729,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '19241729',
#     'name': 'Behrouz Biryani',
#     'url': 'https://www.zomato.com/vellore/behrouz-biryani-katpadi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '10, Andal Nagar, Thiruvalam Road, Katpadi, Vellore',
#      'locality': 'Katpadi',
#      'city': 'Vellore',
#      'city_id': 11330,
#      'latitude': '12.9670799000',
#      'longitude': '79.1535248000',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Katpadi, Vellore'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Biryani, North Indian, Mughlai',
#     'timings': '10 AM to 10 PM',
#     'average_cost_for_two': 700,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Cash', 'Delivery'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/chains/9/19241729/ae42ee0a49892af3433a2e4e1b21ef1d.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.0',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.0'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 378},
#     'all_reviews_count': 19,
#     'photos_url': 'https://www.zomato.com/vellore/behrouz-biryani-katpadi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 27,
#     'menu_url': 'https://www.zomato.com/vellore/behrouz-biryani-katpadi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/9/19241729/ae42ee0a49892af3433a2e4e1b21ef1d.jpg?output-format=webp',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/19241729',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/vellore/behrouz-biryani-katpadi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 7700050050',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': [],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 19007362,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '19007362',
#     'name': 'Rajshree Mithai Chats',
#     'url': 'https://www.zomato.com/vellore/rajshree-mithai-chats-1-katpadi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Shop 23, Vellaikalmedu, Kangeyanallur Road, VIT Opposite of Katpadi, Katpadi, Vellore',
#      'locality': 'Katpadi',
#      'city': 'Vellore',
#      'city_id': 11330,
#      'latitude': '12.9668655038',
#      'longitude': '79.1567402333',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Katpadi, Vellore'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian',
#     'timings': '11 AM to 10 PM',
#     'average_cost_for_two': 200,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Cash',
#      'Dinner',
#      'Lunch',
#      'Delivery',
#      'Credit Card',
#      'Debit Card',
#      'Pure Veg',
#      'Digital Payments Accepted',
#      'Air Conditioned',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.1',
#      'rating_text': 'Average',
#      'rating_color': 'CDD614',
#      'rating_obj': {'title': {'text': '3.1'},
#       'bg_color': {'type': 'lime', 'tint': '500'}},
#      'votes': 759},
#     'all_reviews_count': 7,
#     'photos_url': 'https://www.zomato.com/vellore/rajshree-mithai-chats-1-katpadi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 2,
#     'menu_url': 'https://www.zomato.com/vellore/rajshree-mithai-chats-1-katpadi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/19007362',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/vellore/rajshree-mithai-chats-1-katpadi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9994689481',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Sweet Shop'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 18738926,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '18738926',
#     'name': 'Hyderabad Tandoori Chicken',
#     'url': 'https://www.zomato.com/vellore/hyderabad-tandoori-chicken-thottapalayam?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Bangalore To Chennai Highway, Green Circle, Thottapalayam, Vellore',
#      'locality': 'Thottapalayam',
#      'city': 'Vellore',
#      'city_id': 11330,
#      'latitude': '12.9322617747',
#      'longitude': '79.1372462735',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Thottapalayam, Vellore'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian, Hyderabadi',
#     'timings': '6 PM to 10:30 PM',
#     'average_cost_for_two': 200,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Takeaway Available',
#      'No Alcohol Available',
#      'Cash',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.8',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.8'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 21},
#     'all_reviews_count': 1,
#     'photos_url': 'https://www.zomato.com/vellore/hyderabad-tandoori-chicken-thottapalayam/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 1,
#     'menu_url': 'https://www.zomato.com/vellore/hyderabad-tandoori-chicken-thottapalayam/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18738926',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/vellore/hyderabad-tandoori-chicken-thottapalayam/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 8667536409',
#     'all_reviews': {'reviews': [{'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}}]}

# %%
d1 = json.loads(r)
print(type(d1))
d = d1['restaurants']
print(type(d))
df1 = pd.DataFrame([{'restaurant_name': x['restaurant']['name'], 'restaurant_rating': x['restaurant']['user_rating']['aggregate_rating'],
'restaurant_address': x['restaurant']['location']['address'],'budget_for2people': x['restaurant']['average_cost_for_two'],
'restaurant_photo': x['restaurant']['featured_image'], 'restaurant_url': x['restaurant']['url'] } for x in d])
# Out:
# <class 'dict'>
# <class 'list'>

# %%
df1
# Out:
#               restaurant_name restaurant_rating  \
# 0        Saleem Punjabi Dhaba               3.8
# 1         Tara Maa Restaurant               3.9
# 2                Yaseen Dhaba               3.6
# 3      Rajshree Punjabi Dhaba               3.8
# 4        Saleem Punjabi Dhaba               4.0
# 5      UBQ By Barbeque Nation               3.5
# 6               Punjabi Dhaba               3.6
# 7             Behrouz Biryani               4.0
# 8       Rajshree Mithai Chats               3.1
# 9  Hyderabad Tandoori Chicken               3.8
#
#                                   restaurant_address  budget_for2people  \
# 0        Opposite to VIT Main Gate, Katpadi, Vellore                350
# 1  VIT Main Gate, Kangeyanallore Road, Katpadi, V...                200
# 2  VIT Main Gate, Kangeyanallore Road, Katpadi, V...                300
# 3  14/1 Post Office Street, Opposite to Venus The...                200
# 4  VIT Main Gate, Kangeyanallore Road, Katpadi, V...                250
# 5  16/1, Survey T.S. 316, 316/4B3, First Floor, O...                400
# 6       VIT College, VIT Main Road, Katpadi, Vellore                300
# 7  10, Andal Nagar, Thiruvalam Road, Katpadi, Vel...                700
# 8  Shop 23, Vellaikalmedu, Kangeyanallur Road, VI...                200
# 9  Bangalore To Chennai Highway, Green Circle, Th...                200
#
#                                     restaurant_photo  \
# 0
# 1
# 2
# 3
# 4
# 5  https://b.zmtcdn.com/data/pictures/9/18995459/...
# 6
# 7  https://b.zmtcdn.com/data/pictures/chains/9/19...
# 8
# 9
#
#                                       restaurant_url
# 0  https://www.zomato.com/vellore/saleem-punjabi-...
# 1  https://www.zomato.com/vellore/tara-maa-restau...
# 2  https://www.zomato.com/vellore/yaseen-dhaba-ka...
# 3  https://www.zomato.com/vellore/rajshree-punjab...
# 4  https://www.zomato.com/vellore/saleem-punjabi-...
# 5  https://www.zomato.com/vellore/ubq-by-barbeque...
# 6  https://www.zomato.com/vellore/punjabi-dhaba-k...
# 7  https://www.zomato.com/vellore/behrouz-biryani...
# 8  https://www.zomato.com/vellore/rajshree-mithai...
# 9  https://www.zomato.com/vellore/hyderabad-tando...
