# %%
import requests
import json
import pandas as pd
import numpy as np

# %%
base_url = "https://developers.zomato.com/api/v2.1/"
headers = {'Accept': 'application/json', 'user-key': '7c5b4cda151a68ab847143b592e4c232'}
r = (requests.get(base_url + "locations?query=" + str('Kochi') + "&count=" + str(20), headers=headers).content).decode("utf-8")
json.loads(r)
# Out:
# {'location_suggestions': [{'entity_type': 'city',
#    'entity_id': 9,
#    'title': 'Kochi',
#    'latitude': 9.97,
#    'longitude': 76.28,
#    'city_id': 9,
#    'city_name': 'Kochi',
#    'country_id': 1,
#    'country_name': 'India'}],
#  'status': 'success',
#  'has_more': 0,
#  'has_total': 0,
#  'user_has_addresses': True}

# %%
location_json = json.loads(r)
location_results = len(location_json['location_suggestions'])
lat=location_json["location_suggestions"][0]["latitude"]
lon=location_json["location_suggestions"][0]["longitude"]
city_id=location_json["location_suggestions"][0]["city_id"]
print(location_results,lat,lon,city_id)
# Out:
# 5 9.97 76.28 9

# %%
cuisines_dict={'american': 1,'chinese': 25, 'north indian': 50, 'italian': 55, 'mexican': 73, 'south indian': 85, 'thai': 95}
cuisines = str(cuisines_dict['south indian'])
cuisines = "%2C".join(cuisines.split(","))
headers = {'Accept': 'application/json', 'user-key': '7c5b4cda151a68ab847143b592e4c232'}
r = (requests.get(base_url + "search?q=" + str('') + "&count=" + str(20) + "&lat=" + str(lat) + "&lon=" + str(lon) +\
                  "&cuisines=" + str(cuisines) + "&start=21" , headers=headers).content).decode("utf-8")

# %%
json.loads(r)
# Out:
# {'results_found': 1258,
#  'results_start': 21,
#  'results_shown': 20,
#  'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1,
#       'takeaway': -1},
#      'res_id': 902065,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '902065',
#     'name': 'Chennai Ananda Bhavan',
#     'url': 'https://www.zomato.com/kochi/chennai-ananda-bhavan-kakkanad?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'MRA-376, Seaport - Airport Road, Mavelipuram Colony, Thrikkakara, Vazhakkala, Kakkanad, Kochi',
#      'locality': 'Kakkanad',
#      'city': 'Kochi',
#      'city_id': 9,
#      'latitude': '10.0277120000',
#      'longitude': '76.3370970000',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Kakkanad, Kochi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '7 AM to 11 PM',
#     'average_cost_for_two': 600,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Cash',
#      'Takeaway Available',
#      'No Alcohol Available',
#      'Dinner',
#      'Breakfast',
#      'Lunch',
#      'Indoor Seating',
#      'Table Reservation Not Required'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/902065_RESTAURANT_c2e3ddb3d9d25a4d7f0d33417b366ddb.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '2.7',
#      'rating_text': 'Average',
#      'rating_color': 'FFBA00',
#      'rating_obj': {'title': {'text': '2.7'},
#       'bg_color': {'type': 'yellow', 'tint': '500'}},
#      'votes': 100},
#     'all_reviews_count': 111,
#     'photos_url': 'https://www.zomato.com/kochi/chennai-ananda-bhavan-kakkanad/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 27,
#     'menu_url': 'https://www.zomato.com/kochi/chennai-ananda-bhavan-kakkanad/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/902065_RESTAURANT_c2e3ddb3d9d25a4d7f0d33417b366ddb.jpg?output-format=webp',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/902065',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kochi/chennai-ananda-bhavan-kakkanad/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9847382345',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 902783,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '902783',
#     'name': 'Puttum Kattanum',
#     'url': 'https://www.zomato.com/kochi/puttum-kattanum-kaloor?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '35/563, Banerji Road, Opposite International Stadium, Kaloor, Kochi',
#      'locality': 'Kaloor',
#      'city': 'Kochi',
#      'city_id': 9,
#      'latitude': '10.0011858823',
#      'longitude': '76.3002228364',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Kaloor, Kochi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '4 PM to 12 Midnight',
#     'average_cost_for_two': 250,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Lunch',
#      'Takeaway Available',
#      'No Alcohol Available',
#      'Cash',
#      'Outdoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.6',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.6'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 78},
#     'all_reviews_count': 29,
#     'photos_url': 'https://www.zomato.com/kochi/puttum-kattanum-kaloor/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 35,
#     'menu_url': 'https://www.zomato.com/kochi/puttum-kattanum-kaloor/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/902783',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kochi/puttum-kattanum-kaloor/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9633608009',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 0, 'takeaway': -1},
#      'res_id': 19474024,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '19474024',
#     'name': 'Dakshin Spicy Kitchen',
#     'url': 'https://www.zomato.com/kochi/dakshin-spicy-kitchen-2-kakkanad?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '9/673, 9/418-C1, Edachira, Thrikkakara Circle, Kakkanad, Kochi',
#      'locality': 'Kakkanad',
#      'city': 'Kochi',
#      'city_id': 9,
#      'latitude': '10.0156248000',
#      'longitude': '76.3651314000',
#      'zipcode': '682030',
#      'country_id': 1,
#      'locality_verbose': 'Kakkanad, Kochi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Andhra, South Indian',
#     'timings': '',
#     'average_cost_for_two': 400,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Lunch',
#      'Cash',
#      'Takeaway Available',
#      'Credit Card',
#      'Breakfast',
#      'Dinner',
#      'Delivery',
#      'Debit Card',
#      'Free Parking',
#      'Table booking recommended',
#      'Digital Payments Accepted',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Pure Veg',
#      'All Day Breakfast'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/4/19474024/677f78809d38b43fc4da9bbbea66b052.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '3.9',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.9'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 102},
#     'all_reviews_count': 18,
#     'photos_url': 'https://www.zomato.com/kochi/dakshin-spicy-kitchen-2-kakkanad/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 18,
#     'menu_url': 'https://www.zomato.com/kochi/dakshin-spicy-kitchen-2-kakkanad/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/4/19474024/677f78809d38b43fc4da9bbbea66b052.jpg',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/19474024',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kochi/dakshin-spicy-kitchen-2-kakkanad/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 7994333857',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 900835,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '900835',
#     'name': 'Dosa World',
#     'url': 'https://www.zomato.com/kochi/dosa-world-kacherippady?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Near To Hotel Presidency, Paramara Road, Kacheripady, Kochi',
#      'locality': 'Kacheripady',
#      'city': 'Kochi',
#      'city_id': 9,
#      'latitude': '9.9901611111',
#      'longitude': '76.2849666667',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Kacheripady, Kochi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian, Kerala',
#     'timings': '8 AM to 11 PM (Mon-Sun)',
#     'average_cost_for_two': 400,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'Lunch',
#      'Breakfast',
#      'Dinner',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.8',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.8'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 297},
#     'all_reviews_count': 20,
#     'photos_url': 'https://www.zomato.com/kochi/dosa-world-kacherippady/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 26,
#     'menu_url': 'https://www.zomato.com/kochi/dosa-world-kacherippady/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/900835',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kochi/dosa-world-kacherippady/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9746474984',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 902812,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '902812',
#     'name': 'Masafi Restaurant',
#     'url': 'https://www.zomato.com/kochi/masafi-restaurant-palarivattom?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '33/2171.A1, Bye Pass Junction, Civil Lines, Palarivattom, Kochi',
#      'locality': 'Palarivattom',
#      'city': 'Kochi',
#      'city_id': 9,
#      'latitude': '9.9984802000',
#      'longitude': '76.3119364000',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Palarivattom, Kochi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Kerala, South Indian',
#     'timings': '11 AM to 12 Midnight',
#     'average_cost_for_two': 350,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Lunch',
#      'Cash',
#      'Credit Card',
#      'No Alcohol Available',
#      'Dinner',
#      'Takeaway Available',
#      'Debit Card',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.8',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.8'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 43},
#     'all_reviews_count': 12,
#     'photos_url': 'https://www.zomato.com/kochi/masafi-restaurant-palarivattom/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 7,
#     'menu_url': 'https://www.zomato.com/kochi/masafi-restaurant-palarivattom/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/902812',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kochi/masafi-restaurant-palarivattom/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '0484 4852054',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 1, 'takeaway': -1},
#      'res_id': 900819,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '900819',
#     'name': 'Hotel Aryas',
#     'url': 'https://www.zomato.com/kochi/hotel-aryas-kaloor?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'KK Road, Opposite AJ Hall, Kaloor, Kochi',
#      'locality': 'Kaloor',
#      'city': 'Kochi',
#      'city_id': 9,
#      'latitude': '9.9936370000',
#      'longitude': '76.2923140000',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Kaloor, Kochi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '7 AM to 10 PM',
#     'average_cost_for_two': 600,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Lunch',
#      'Cash',
#      'Takeaway Available',
#      'No Alcohol Available',
#      'Dinner',
#      'Delivery',
#      'Breakfast',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '4.0',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.0'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 239},
#     'all_reviews_count': 13,
#     'photos_url': 'https://www.zomato.com/kochi/hotel-aryas-kaloor/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 13,
#     'menu_url': 'https://www.zomato.com/kochi/hotel-aryas-kaloor/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/900819',
#     'order_url': 'https://www.zomato.com/kochi/hotel-aryas-kaloor/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kochi/hotel-aryas-kaloor/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '0484 2535303, +91 9447594599',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 903675,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '903675',
#     'name': "Director's Special",
#     'url': 'https://www.zomato.com/kochi/directors-special-kadavanthra?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '55/1808, K.P. Vallon Road, Kadavanthara P.O, Kadavanthra, Kochi',
#      'locality': 'Kadavanthra',
#      'city': 'Kochi',
#      'city_id': 9,
#      'latitude': '9.9621749313',
#      'longitude': '76.3008809835',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Kadavanthra, Kochi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Kerala, South Indian, Beverages',
#     'timings': '11am – 11pm (Mon, Tue, Wed, Thu, Fri, Sun), 1:30pm – 11pm (Sat)',
#     'average_cost_for_two': 500,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Debit Card',
#      'Cash',
#      'Takeaway Available',
#      'Lunch',
#      'Credit Card',
#      'Delivery',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/5/903675/decbae9ebd773dd2332d109ba4239b3e.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '3.4',
#      'rating_text': 'Average',
#      'rating_color': 'CDD614',
#      'rating_obj': {'title': {'text': '3.4'},
#       'bg_color': {'type': 'lime', 'tint': '500'}},
#      'votes': 431},
#     'all_reviews_count': 16,
#     'photos_url': 'https://www.zomato.com/kochi/directors-special-kadavanthra/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 14,
#     'menu_url': 'https://www.zomato.com/kochi/directors-special-kadavanthra/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/5/903675/decbae9ebd773dd2332d109ba4239b3e.jpg',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/903675',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kochi/directors-special-kadavanthra/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 8593940101',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 901086,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '901086',
#     'name': 'Cochin Palace Restaurant',
#     'url': 'https://www.zomato.com/kochi/cochin-palace-restaurant-kadavanthra?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'K.P Vallom Road, Near Silver Line Hospital, Kadavanthra, Kochi',
#      'locality': 'Kadavanthra',
#      'city': 'Kochi',
#      'city_id': 9,
#      'latitude': '9.9635707720',
#      'longitude': '76.3005788997',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Kadavanthra, Kochi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian, Kerala',
#     'timings': '7 AM to 10 PM',
#     'average_cost_for_two': 600,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Cash',
#      'Delivery',
#      'Credit Card',
#      'Lunch',
#      'Takeaway Available',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Wifi'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.5',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.5'},
#       'bg_color': {'type': 'lime', 'tint': '500'}},
#      'votes': 23},
#     'all_reviews_count': 7,
#     'photos_url': 'https://www.zomato.com/kochi/cochin-palace-restaurant-kadavanthra/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 54,
#     'menu_url': 'https://www.zomato.com/kochi/cochin-palace-restaurant-kadavanthra/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'medio_provider': 1,
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/901086',
#     'is_table_reservation_supported': 1,
#     'has_table_booking': 1,
#     'book_url': 'https://www.zomato.com/kochi/cochin-palace-restaurant-kadavanthra/book?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'events_url': 'https://www.zomato.com/kochi/cochin-palace-restaurant-kadavanthra/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 8943338846, 0484 2315191',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 900192,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '900192',
#     'name': "Shenoy's Pure Veg",
#     'url': 'https://www.zomato.com/kochi/shenoys-pure-veg-aluva?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'NH Bypass, Aluva, Kochi',
#      'locality': 'Aluva',
#      'city': 'Kochi',
#      'city_id': 9,
#      'latitude': '10.1033138889',
#      'longitude': '76.3493416667',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Aluva, Kochi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '7:30 AM to 9:30 PM (Mon-Sun)',
#     'average_cost_for_two': 300,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'No Alcohol Available',
#      'Breakfast',
#      'Cash',
#      'Dinner',
#      'Lunch',
#      'Pure Veg',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.8',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.8'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 98},
#     'all_reviews_count': 20,
#     'photos_url': 'https://www.zomato.com/kochi/shenoys-pure-veg-aluva/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 15,
#     'menu_url': 'https://www.zomato.com/kochi/shenoys-pure-veg-aluva/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/900192',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kochi/shenoys-pure-veg-aluva/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9846120884',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 900095,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '900095',
#     'name': 'Kempu Coffee Shop',
#     'url': 'https://www.zomato.com/kochi/kempu-coffee-shop-pallimukku?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Gandhi Square, DH Road, Ernakulam',
#      'locality': 'BTH Bharat Hotel',
#      'city': 'Kochi',
#      'city_id': 9,
#      'latitude': '9.9675916667',
#      'longitude': '76.2813944444',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'BTH Bharat Hotel, Kochi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '3 PM to 2 AM (Mon-Sun)',
#     'average_cost_for_two': 200,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Cash',
#      'No Alcohol Available',
#      'Dinner',
#      'Indoor Seating',
#      'Wifi',
#      'Pure Veg'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/900095_RESTAURANT_76c257cbc82e541919ba017f73650172.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '3.1',
#      'rating_text': 'Average',
#      'rating_color': 'CDD614',
#      'rating_obj': {'title': {'text': '3.1'},
#       'bg_color': {'type': 'lime', 'tint': '500'}},
#      'votes': 44},
#     'all_reviews_count': 27,
#     'photos_url': 'https://www.zomato.com/kochi/kempu-coffee-shop-pallimukku/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 52,
#     'menu_url': 'https://www.zomato.com/kochi/kempu-coffee-shop-pallimukku/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/900095_RESTAURANT_76c257cbc82e541919ba017f73650172.jpg',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/900095',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kochi/kempu-coffee-shop-pallimukku/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '0484 3295090, 0484 2353501',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 1, 'takeaway': -1},
#      'res_id': 900742,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '900742',
#     'name': 'Hotel Anandhaas - Edappally',
#     'url': 'https://www.zomato.com/kochi/hotel-anandhaas-edappally-edappally?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Opposite Lulu Mall, Edappally, Kochi',
#      'locality': 'Edappally',
#      'city': 'Kochi',
#      'city_id': 9,
#      'latitude': '10.0257972222',
#      'longitude': '76.3067388889',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Edappally, Kochi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian, Kerala',
#     'timings': '7 AM to 8 PM',
#     'average_cost_for_two': 250,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Delivery',
#      'Breakfast',
#      'Lunch',
#      'Cash',
#      'Takeaway Available',
#      'Debit Card',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/900742_RESTAURANT_a7fbd4fc1eba5f2f64dacd678bd01d75.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '3.6',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.6'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 1499},
#     'all_reviews_count': 10,
#     'photos_url': 'https://www.zomato.com/kochi/hotel-anandhaas-edappally-edappally/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 4,
#     'menu_url': 'https://www.zomato.com/kochi/hotel-anandhaas-edappally-edappally/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/900742_RESTAURANT_a7fbd4fc1eba5f2f64dacd678bd01d75.jpg',
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/900742',
#     'order_url': 'https://www.zomato.com/kochi/hotel-anandhaas-edappally-edappally/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kochi/hotel-anandhaas-edappally-edappally/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9995246091',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 902632,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '902632',
#     'name': "Shibu's Puttu Kada",
#     'url': 'https://www.zomato.com/kochi/shibus-puttu-kada-thevara?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Boat Jetty Rd, Kumbalam, Ernakulam, Kochi',
#      'locality': 'Thevera',
#      'city': 'Kochi',
#      'city_id': 9,
#      'latitude': '9.9430453000',
#      'longitude': '76.2947488000',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Thevera, Kochi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian, Kerala',
#     'timings': '6 PM to 2 AM',
#     'average_cost_for_two': 500,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Cash',
#      'Takeaway Available',
#      'Dinner',
#      'Indoor Seating',
#      'Pure Veg',
#      'Free Parking'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.7',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.7'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 28},
#     'all_reviews_count': 12,
#     'photos_url': 'https://www.zomato.com/kochi/shibus-puttu-kada-thevara/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 9,
#     'menu_url': 'https://www.zomato.com/kochi/shibus-puttu-kada-thevara/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/902632',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kochi/shibus-puttu-kada-thevara/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9847090859',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 900825,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '900825',
#     'name': 'New Jaya Restaurant',
#     'url': 'https://www.zomato.com/kochi/new-jaya-restaurant-palarivattom?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Next To Axis Bank, Palarivattom, Kochi',
#      'locality': 'Palarivattom',
#      'city': 'Kochi',
#      'city_id': 9,
#      'latitude': '10.0022055556',
#      'longitude': '76.3052444444',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Palarivattom, Kochi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Tea, South Indian, Roast Chicken, Kerala',
#     'timings': '6:30 AM to 8:30 PM (Mon-Sun)',
#     'average_cost_for_two': 500,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Cash',
#      'Breakfast',
#      'Lunch',
#      'No Alcohol Available',
#      'Dinner',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/900825_RESTAURANT_a3cd9a1e91b993e397252a1aac73e248.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '3.8',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.8'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 41},
#     'all_reviews_count': 15,
#     'photos_url': 'https://www.zomato.com/kochi/new-jaya-restaurant-palarivattom/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 2,
#     'menu_url': 'https://www.zomato.com/kochi/new-jaya-restaurant-palarivattom/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/900825_RESTAURANT_a3cd9a1e91b993e397252a1aac73e248.jpg?output-format=webp',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/900825',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kochi/new-jaya-restaurant-palarivattom/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9388608839, 0484 6491589',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 902096,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '902096',
#     'name': 'The Southern Kitchen - Dosa Lounge',
#     'url': 'https://www.zomato.com/kochi/the-southern-kitchen-dosa-lounge-2-kakkanad?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Carnival Food Court, Near Infopark, Edachira, Kakkanad, Kochi',
#      'locality': 'Kakkanad',
#      'city': 'Kochi',
#      'city_id': 9,
#      'latitude': '10.0151898910',
#      'longitude': '76.3645526022',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Kakkanad, Kochi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '8 AM to 11 PM',
#     'average_cost_for_two': 350,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['No Alcohol Available',
#      'Takeaway Available',
#      'Credit Card',
#      'Lunch',
#      'Dinner',
#      'Delivery',
#      'Cash',
#      'Debit Card',
#      'Breakfast',
#      'Indoor Seating',
#      'Digital Payments Accepted',
#      'Air Conditioned',
#      'Sodexo'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/902096_RESTAURANT_e6236697c9f60012a26376389431507a.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '3.6',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.6'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 267},
#     'all_reviews_count': 38,
#     'photos_url': 'https://www.zomato.com/kochi/the-southern-kitchen-dosa-lounge-2-kakkanad/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 8,
#     'menu_url': 'https://www.zomato.com/kochi/the-southern-kitchen-dosa-lounge-2-kakkanad/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/902096_RESTAURANT_e6236697c9f60012a26376389431507a.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/902096',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kochi/the-southern-kitchen-dosa-lounge-2-kakkanad/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9074994103',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 0, 'takeaway': -1},
#      'res_id': 902641,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '902641',
#     'name': 'Hotel Mishwar',
#     'url': 'https://www.zomato.com/kochi/hotel-mishwar-tripunithura?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '50/491, Petta Jn , Poonithura, Ernakulam, Kochi',
#      'locality': 'Tripunithura',
#      'city': 'Kochi',
#      'city_id': 9,
#      'latitude': '9.9493401000',
#      'longitude': '76.3321517000',
#      'zipcode': '682301',
#      'country_id': 1,
#      'locality_verbose': 'Tripunithura, Kochi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian, Kerala',
#     'timings': '11 AM – 11 PM',
#     'average_cost_for_two': 350,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Cash',
#      'Dinner',
#      'Takeaway Available',
#      'Lunch',
#      'Indoor Seating',
#      'Pure Veg',
#      'Free Parking'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.8',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.8'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 237},
#     'all_reviews_count': 1,
#     'photos_url': 'https://www.zomato.com/kochi/hotel-mishwar-tripunithura/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 0,
#     'menu_url': 'https://www.zomato.com/kochi/hotel-mishwar-tripunithura/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/902641',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kochi/hotel-mishwar-tripunithura/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9249863041',
#     'all_reviews': {'reviews': [{'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 19189339,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '19189339',
#     'name': '11 To 11 Meals - Chedathies Kitchen',
#     'url': 'https://www.zomato.com/kochi/11-to-11-meals-chedathies-kitchen-vyttila?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '45/1820a, Nandhanath Kochacko Road, Chakkaraparambu, Thammanam, Thrikkakara Circle, Vyttila, Kochi',
#      'locality': 'Vyttila',
#      'city': 'Kochi',
#      'city_id': 9,
#      'latitude': '9.9883415547',
#      'longitude': '76.3149824181',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Vyttila, Kochi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '11 AM to 10 PM',
#     'average_cost_for_two': 550,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'Cash',
#      'Takeaway Available',
#      'Dinner',
#      'Credit Card',
#      'Lunch',
#      'Debit Card',
#      'Indoor Seating',
#      'Digital Payments Accepted'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '4.0',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.0'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 860},
#     'all_reviews_count': 21,
#     'photos_url': 'https://www.zomato.com/kochi/11-to-11-meals-chedathies-kitchen-vyttila/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 0,
#     'menu_url': 'https://www.zomato.com/kochi/11-to-11-meals-chedathies-kitchen-vyttila/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/19189339',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kochi/11-to-11-meals-chedathies-kitchen-vyttila/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9526415186',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 903160,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '903160',
#     'name': 'Puttu Kada',
#     'url': 'https://www.zomato.com/kochi/puttu-kada-thevara?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Pandit karuppan road, thevara ,kochi\n\n',
#      'locality': 'Thevera',
#      'city': 'Kochi',
#      'city_id': 9,
#      'latitude': '9.9456096403',
#      'longitude': '76.2935689464',
#      'zipcode': '682013',
#      'country_id': 1,
#      'locality_verbose': 'Thevera, Kochi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian, Kerala',
#     'timings': '8 AM to 11 PM',
#     'average_cost_for_two': 200,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Takeaway Available',
#      'Lunch',
#      'Cash',
#      'Breakfast',
#      'Delivery',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.7',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.7'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 280},
#     'all_reviews_count': 4,
#     'photos_url': 'https://www.zomato.com/kochi/puttu-kada-thevara/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 0,
#     'menu_url': 'https://www.zomato.com/kochi/puttu-kada-thevara/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/903160',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kochi/puttu-kada-thevara/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9846055505',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 1, 'takeaway': -1},
#      'res_id': 900765,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '900765',
#     'name': 'Hotel Lucky Star',
#     'url': 'https://www.zomato.com/kochi/hotel-lucky-star-fort-kochi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '1/1107, 1/1085, Kunnumpuram Junction, Fort Kochi, Kochi',
#      'locality': 'Fort Kochi',
#      'city': 'Kochi',
#      'city_id': 9,
#      'latitude': '9.9641777778',
#      'longitude': '76.2455222222',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Fort Kochi, Kochi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '6 AM to 12 Midnight (Mon-Sun)',
#     'average_cost_for_two': 500,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Lunch',
#      'Cash',
#      'Breakfast',
#      'No Alcohol Available',
#      'Dinner',
#      'Takeaway Available',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.6',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.6'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 231},
#     'all_reviews_count': 13,
#     'photos_url': 'https://www.zomato.com/kochi/hotel-lucky-star-fort-kochi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 13,
#     'menu_url': 'https://www.zomato.com/kochi/hotel-lucky-star-fort-kochi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/900765',
#     'order_url': 'https://www.zomato.com/kochi/hotel-lucky-star-fort-kochi/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kochi/hotel-lucky-star-fort-kochi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 8943743522',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 95130,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '95130',
#     'name': 'Kadaloram',
#     'url': 'https://www.zomato.com/kochi/kadaloram-mg-road?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Abad Plaza,, kochi, MG Road, Kochi',
#      'locality': 'Abad Plaza, Kacheripady',
#      'city': 'Kochi',
#      'city_id': 9,
#      'latitude': '9.9784740000',
#      'longitude': '76.2832290000',
#      'zipcode': '0',
#      'country_id': 1,
#      'locality_verbose': 'Abad Plaza, Kacheripady, Kochi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Kerala, South Indian',
#     'timings': '12 Noon to 3:30 PM, 7 PM to 12:30 AM (Mon-Sun)',
#     'average_cost_for_two': 600,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'Dinner',
#      'Credit Card',
#      'Lunch',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Catering Available'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '2.9',
#      'rating_text': 'Average',
#      'rating_color': 'FFBA00',
#      'rating_obj': {'title': {'text': '2.9'},
#       'bg_color': {'type': 'yellow', 'tint': '500'}},
#      'votes': 35},
#     'all_reviews_count': 16,
#     'photos_url': 'https://www.zomato.com/kochi/kadaloram-mg-road/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 11,
#     'menu_url': 'https://www.zomato.com/kochi/kadaloram-mg-road/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/95130',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kochi/kadaloram-mg-road/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': 'Not available for this place',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 19150148,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '19150148',
#     'name': 'Koyikodan',
#     'url': 'https://www.zomato.com/kochi/koyikodan-vyttila?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '49/326, 327, Vyttila, Kochi',
#      'locality': 'Vyttila',
#      'city': 'Kochi',
#      'city_id': 9,
#      'latitude': '9.9698461157',
#      'longitude': '76.3185453415',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Vyttila, Kochi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian, Kerala',
#     'timings': '7:30 AM to 3 AM',
#     'average_cost_for_two': 250,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'Breakfast',
#      'Dinner',
#      'Cash',
#      'Takeaway Available',
#      'Lunch',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.7',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.7'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 666},
#     'all_reviews_count': 16,
#     'photos_url': 'https://www.zomato.com/kochi/koyikodan-vyttila/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 0,
#     'menu_url': 'https://www.zomato.com/kochi/koyikodan-vyttila/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/19150148',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kochi/koyikodan-vyttila/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 8289957271',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}}]}

# %%
budget = 'expnsv'

# %%
d = json.loads(r)
res_list = d['restaurants']
res_frame = pd.DataFrame([{'name': x['restaurant']['name'], 'rating': x['restaurant']['user_rating']['aggregate_rating'],
'address': x['restaurant']['location']['address'],'cost_for_2': x['restaurant']['average_cost_for_two']} for x in res_list])
res_frame['rating'] = np.where((res_frame.rating == 0),'0.01',res_frame.rating)
res_frame.sort_values(by = 'rating', ascending = False,inplace = True)

# %%
res_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 5 to 0
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        20 non-null     object
#  1   rating      20 non-null     object
#  2   address     20 non-null     object
#  3   cost_for_2  20 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 800.0+ bytes

# %%
res_frame
# Out:
#                                    name rating  \
# 5                           Hotel Aryas    4.0
# 15  11 To 11 Meals - Chedathies Kitchen    4.0
# 2                 Dakshin Spicy Kitchen    3.9
# 3                            Dosa World    3.8
# 4                     Masafi Restaurant    3.8
# 8                     Shenoy's Pure Veg    3.8
# 14                        Hotel Mishwar    3.8
# 12                  New Jaya Restaurant    3.8
# 19                            Koyikodan    3.7
# 16                           Puttu Kada    3.7
# 11                   Shibu's Puttu Kada    3.7
# 13   The Southern Kitchen - Dosa Lounge    3.6
# 17                     Hotel Lucky Star    3.6
# 10          Hotel Anandhaas - Edappally    3.6
# 1                       Puttum Kattanum    3.6
# 7              Cochin Palace Restaurant    3.5
# 6                    Director's Special    3.4
# 9                     Kempu Coffee Shop    3.1
# 18                            Kadaloram    2.9
# 0                 Chennai Ananda Bhavan    2.7
#
#                                               address  cost_for_2
# 5            KK Road, Opposite AJ Hall, Kaloor, Kochi         600
# 15  45/1820a, Nandhanath Kochacko Road, Chakkarapa...         550
# 2   9/673, 9/418-C1, Edachira, Thrikkakara Circle,...         400
# 3   Near To Hotel Presidency, Paramara Road, Kache...         400
# 4   33/2171.A1, Bye Pass Junction, Civil Lines, Pa...         350
# 8                             NH Bypass, Aluva, Kochi         300
# 14    50/491, Petta Jn , Poonithura, Ernakulam, Kochi         350
# 12             Next To Axis Bank, Palarivattom, Kochi         500
# 19                        49/326, 327, Vyttila, Kochi         250
# 16           Pandit karuppan road, thevara ,kochi\n\n         200
# 11          Boat Jetty Rd, Kumbalam, Ernakulam, Kochi         500
# 13  Carnival Food Court, Near Infopark, Edachira, ...         350
# 17  1/1107, 1/1085, Kunnumpuram Junction, Fort Koc...         500
# 10               Opposite Lulu Mall, Edappally, Kochi         250
# 1   35/563, Banerji Road, Opposite International S...         250
# 7   K.P Vallom Road, Near Silver Line Hospital, Ka...         600
# 6   55/1808, K.P. Vallon Road, Kadavanthara P.O, K...         500
# 9                   Gandhi Square, DH Road, Ernakulam         200
# 18                 Abad Plaza,, kochi, MG Road, Kochi         600
# 0   MRA-376, Seaport - Airport Road, Mavelipuram C...         600

# %%
if budget == 'budg':
    final_frame = res_frame.loc[(res_frame.cost_for_2 <= 300)][:10].reset_index()
elif budget == 'norml':
    final_frame = res_frame.loc[(res_frame.cost_for_2 > 300) & (res_frame.cost_for_2 <= 700)][:10].reset_index()
elif budget == 'expnsv':
    final_frame = res_frame.loc[(res_frame.cost_for_2 > 700)][:10].reset_index()
else:
    final_frame = res_frame[:10]

# %%
email_response = 'Below are the top restaurants for your search: \n'
chat_response = ''
for i in range(len(final_frame)):
    j = i
    email_response += str(j+1) + ". " + final_frame.loc[i,'name'] + " with average rating of " + str(final_frame.loc[i,'rating']) + " found at " \
    + final_frame.loc[i,'address'] + " and the average cost for 2 would be INR " + str(final_frame.loc[i,'cost_for_2']) + ". \n"
if len(final_frame) <5:
    chat_response = 'Got ' + str(len(final_frame)) + ' restaurants that matched your criteria. Try with a higher budget if needed. \n' \
                    + email_response
elif len(final_frame) == 5:
    chat_response = email_response
elif len(final_frame) > 5:
    for i in range(5):
        j = i
        chat_response += 'Below are the top restaurants for your search: \n' + str(j+1) + ". " + final_frame.loc[i,'name'] + \
        " with average rating of " + str(final_frame.loc[i,'rating']) + " found at " \
        + final_frame.loc[i,'address'] + " and the average cost for 2 would be INR " + str(final_frame.loc[i,'cost_for_2']) + ". \n"

# %%
email_response
# Out:
# "Below are the top restaurants for your search: \n1. Andhikkadai with average rating of 4.4 found at 20, Dhandeeswaram Main Road, Velachery, Chennai and the average cost for 2 would be INR 200. \n2. Eating Circles with average rating of 4.4 found at 6, CP Ramaswamy Road, Alwarpet, Chennai and the average cost for 2 would be INR 250. \n3. Rayar's Mess with average rating of 4.4 found at 31, Arundale Street, Mylapore, Chennai and the average cost for 2 would be INR 100. \n4. Murugan Idli Shop with average rating of 4.2 found at 77-1/A, G.N. Chetty Road, T. Nagar, Chennai and the average cost for 2 would be INR 200. \n5. Murugan Idli Shop with average rating of 4.1 found at 129/28, 100 Feet Road, Velachery, Chennai and the average cost for 2 would be INR 200. \n6. Mylai Karpagambal Mess with average rating of 4.1 found at 20, East Mada Street, Mylapore, Chennai and the average cost for 2 would be INR 200. \n7. Murugan Idli Shop with average rating of 4.1 found at 149/1, 6th Avenue, Opposite Vilankanni Church, Besant Nagar, Chennai and the average cost for 2 would be INR 200. \n8. Kozhi Idli with average rating of 4.1 found at 155, Avvai Shanmugam Salai, Near AIADMK Party Office, Gopalapuram, Chennai and the average cost for 2 would be INR 300. \n9. Idlies with average rating of 4.0 found at 17, 18th Avenue, Ashok Nagar, Chennai and the average cost for 2 would be INR 250. \n10. National Lodge with average rating of 4.0 found at 112, Govindappa Naickan Street, Sowcarpet, Chennai and the average cost for 2 would be INR 300. \n"

# %%
chat_response
# Out:
# "Below are the top restaurants for your search: \n1. Andhikkadai with average rating of 4.4 found at 20, Dhandeeswaram Main Road, Velachery, Chennai and the average cost for 2 would be INR 200. \nBelow are the top restaurants for your search: \n2. Eating Circles with average rating of 4.4 found at 6, CP Ramaswamy Road, Alwarpet, Chennai and the average cost for 2 would be INR 250. \nBelow are the top restaurants for your search: \n3. Rayar's Mess with average rating of 4.4 found at 31, Arundale Street, Mylapore, Chennai and the average cost for 2 would be INR 100. \nBelow are the top restaurants for your search: \n4. Murugan Idli Shop with average rating of 4.2 found at 77-1/A, G.N. Chetty Road, T. Nagar, Chennai and the average cost for 2 would be INR 200. \nBelow are the top restaurants for your search: \n5. Murugan Idli Shop with average rating of 4.1 found at 129/28, 100 Feet Road, Velachery, Chennai and the average cost for 2 would be INR 200. \n"

# %%
final_frame
# Out:
#    index                 name rating  \
# 0     19      Ovenstory Pizza    4.0
# 1      6               Kalo's    4.0
# 2     17          Pizza Dough    3.8
# 3      8     Midnight Madness    3.7
# 4     10  The Shack @ Elliots    3.5
#
#                                              address  cost_for_2
# 0  No. 19/8, Pushpa Nagar Main Road, Nungambakkam...         400
# 1  Shop 8, Thiruvalluvar Nagar, Besant Nagar, Che...         500
# 2  114, Ground Floor, Bazaar Road, Sadhasivam Nag...         600
# 3  1/1, F-3, 1st Floor, Sindhuja Complex, 29th Cr...         450
# 4  71, Odaikuppam, Near Ashtalakshmi Temple, Besa...         700

# %%
res_frame.loc[(res_frame.cost_for_2 <= 300)][:10]
# Out:
#                       name rating  \
# 3              Andhikkadai    4.4
# 1           Eating Circles    4.4
# 2             Rayar's Mess    4.4
# 8        Murugan Idli Shop    4.2
# 18       Murugan Idli Shop    4.1
# 11  Mylai Karpagambal Mess    4.1
# 9        Murugan Idli Shop    4.1
# 19              Kozhi Idli    4.1
# 13                  Idlies    4.0
# 16          National Lodge    4.0
#
#                                               address  cost_for_2
# 3     20, Dhandeeswaram Main Road, Velachery, Chennai         200
# 1             6, CP Ramaswamy Road, Alwarpet, Chennai         250
# 2              31, Arundale Street, Mylapore, Chennai         100
# 8         77-1/A, G.N. Chetty Road, T. Nagar, Chennai         200
# 18          129/28, 100 Feet Road, Velachery, Chennai         200
# 11            20, East Mada Street, Mylapore, Chennai         200
# 9   149/1, 6th Avenue, Opposite Vilankanni Church,...         200
# 19  155, Avvai Shanmugam Salai, Near AIADMK Party ...         300
# 13              17, 18th Avenue, Ashok Nagar, Chennai         250
# 16  112, Govindappa Naickan Street, Sowcarpet, Che...         300

# %%
res_frame.loc[(res_frame.cost_for_2 > 700)][:10]
# Out:
#                                          name rating  \
# 12            Southern Spice - Taj Coromandel    4.7
# 10  Dakshin - Crowne Plaza Chennai Adyar Park    4.5
# 7                                  Savya Rasa    4.4
# 14                                   Aadhirai    4.1
# 17                                Kumbakkarai    4.1
#
#                                               address  cost_for_2
# 12  Taj Coromandel, 37, Mahatma Gandhi Road, Nunga...        3000
# 10  NO.132 T T K ROAD CHENNAI ,Chennai(Tamil Nadu)...        2500
# 7    2/10, Gandhi Mandapam Road, Kotturpuram, Chennai        1600
# 14  31, Jambulingam Street, Off Valluvar Kottam Hi...        1000
# 17  40/156, Kodambakkam High Road, Nungambakkam, C...         850

# %%
res_frame[:50]
# Out:
#                                          name rating  \
# 12            Southern Spice - Taj Coromandel    4.7
# 0                       Prems Graama Bhojanam    4.6
# 10  Dakshin - Crowne Plaza Chennai Adyar Park    4.5
# 3                                 Andhikkadai    4.4
# 6                            That Mallu Joint    4.4
# 7                                  Savya Rasa    4.4
# 1                              Eating Circles    4.4
# 2                                Rayar's Mess    4.4
# 8                           Murugan Idli Shop    4.2
# 4                         Nellai Vairamaligai    4.2
# 14                                   Aadhirai    4.1
# 18                          Murugan Idli Shop    4.1
# 17                                Kumbakkarai    4.1
# 11                     Mylai Karpagambal Mess    4.1
# 9                           Murugan Idli Shop    4.1
# 5                                 Mana Andhra    4.1
# 19                                 Kozhi Idli    4.1
# 13                                     Idlies    4.0
# 15                          Shree Konar Vilas    4.0
# 16                             National Lodge    4.0
#
#                                               address  cost_for_2
# 12  Taj Coromandel, 37, Mahatma Gandhi Road, Nunga...        3000
# 0   23/10, 3rd Main Road, Kasturba Nagar, Adyar, C...         500
# 10  NO.132 T T K ROAD CHENNAI ,Chennai(Tamil Nadu)...        2500
# 3     20, Dhandeeswaram Main Road, Velachery, Chennai         200
# 6   2nd Floor, PMG Complex, GN Chetty Road, T. Nag...         600
# 7    2/10, Gandhi Mandapam Road, Kotturpuram, Chennai        1600
# 1             6, CP Ramaswamy Road, Alwarpet, Chennai         250
# 2              31, Arundale Street, Mylapore, Chennai         100
# 8         77-1/A, G.N. Chetty Road, T. Nagar, Chennai         200
# 4   60, Thirumalai Pillai Road, Rama Kamath Puram,...         500
# 14  31, Jambulingam Street, Off Valluvar Kottam Hi...        1000
# 18          129/28, 100 Feet Road, Velachery, Chennai         200
# 17  40/156, Kodambakkam High Road, Nungambakkam, C...         850
# 11            20, East Mada Street, Mylapore, Chennai         200
# 9   149/1, 6th Avenue, Opposite Vilankanni Church,...         200
# 5   18/24, Khader Nawaskhan Road, Nungambakkam, Ch...         600
# 19  155, Avvai Shanmugam Salai, Near AIADMK Party ...         300
# 13              17, 18th Avenue, Ashok Nagar, Chennai         250
# 15  128, Perambur Barracks Road, Purasavakkam, Che...         500
# 16  112, Govindappa Naickan Street, Sowcarpet, Che...         300

# %%
df2 = df1.sort_values(by = 'rating', ascending = False)

# %%
abc = ''
for x in df2:
    response = df2['name'] + " with average rating of " + df2['rating'] + " found at " \
    + df2['address'] + " and the average cost for 2 would be INR " + df2['cost_for_2'] + ". \n"
for a in response:
    abc += str(a)

# %%
response = ''
for i in range(len(df1)):
    j = i
    response += str(j+1) + ". " + df1.loc[i,'name'] + " with average rating of " + str(df1.loc[i,'rating']) + " found at " \
    + df1.loc[i,'address'] + " and the average cost for 2 would be INR " + str(df1.loc[i,'cost_for_2']) + ". \n"

# %%
response
# Out:
# "1. Pedreno's with average rating of 4.1 found at 113/114, PS Sivaswami Salai, Mylapore, Chennai and the average cost for 2 would be INR 1200. \n2. Joker's Kitchen with average rating of 4.3 found at 94/1, Door 211/1, TTK Road, Near Ethiraj Kalayana Mandapam, Alwarpet, Chennai and the average cost for 2 would be INR 800. \n3. Asvah 24 with average rating of 4.2 found at 24 Beach Road, Sri Kapaleeshwar Nagar, Neelangarai, Chennai and the average cost for 2 would be INR 1700. \n4. Tuscana Pizzeria with average rating of 4.1 found at 19, 3rd Street, Wallace Garden Road, Nungambakkam, Chennai and the average cost for 2 would be INR 1200. \n5. Tryst Cafe with average rating of 4.1 found at 4/359, Gatsby Village, East Coast Road, Neelangarai, Chennai and the average cost for 2 would be INR 800. \n6. Jonah's Bistro with average rating of 4.2 found at G-12, Phoenix Mall, O 66/N 142, Velachery Road, Velachery, Chennai and the average cost for 2 would be INR 800. \n7. Kalo's with average rating of 4.0 found at Shop 8, Thiruvalluvar Nagar, Besant Nagar, Chennai and the average cost for 2 would be INR 500. \n8. Upper Deck - Taj Fisherman's Cove Resort & Spa with average rating of 4.3 found at Vivanta by Taj  Fisherman's Cove, Covelong Beach, Off East Coast Road (ECR), Kovalam, Chennai and the average cost for 2 would be INR 3500. \n9. Midnight Madness with average rating of 3.7 found at 1/1, F-3, 1st Floor, Sindhuja Complex, 29th Cross Street, Indira Nagar, Adyar, Chennai and the average cost for 2 would be INR 450. \n10. Ox & Tomato with average rating of 4.0 found at 2/15, Ganapathy Colony, Main Road, Near Bank of Baroda ATM, Sri Ram Nagar, Teynampet, Chennai and the average cost for 2 would be INR 850. \n"

# %%
type(str(df2['name']))
# Out:
# str

# %%
abc
# Out:
# "Joker's Kitchen with average rating of 4.3 found at 94/1, Door 211/1, TTK Road, Near Ethiraj Kalayana Mandapam, Alwarpet, Chennai and the average cost for 2 would be INR 1     800\n7    3500\n2    1700\n5     800\n0    1200\n3    1200\n4     800\n6     500\n9     850\n8     450\nName: cost_for_2, dtype: int64. \nUpper Deck - Taj Fisherman's Cove Resort & Spa with average rating of 4.3 found at Vivanta by Taj  Fisherman's Cove, Covelong Beach, Off East Coast Road (ECR), Kovalam, Chennai and the average cost for 2 would be INR 1     800\n7    3500\n2    1700\n5     800\n0    1200\n3    1200\n4     800\n6     500\n9     850\n8     450\nName: cost_for_2, dtype: int64. \nAsvah 24 with average rating of 4.2 found at 24 Beach Road, Sri Kapaleeshwar Nagar, Neelangarai, Chennai and the average cost for 2 would be INR 1     800\n7    3500\n2    1700\n5     800\n0    1200\n3    1200\n4     800\n6     500\n9     850\n8     450\nName: cost_for_2, dtype: int64. \nJonah's Bistro with average rating of 4.2 found at G-12, Phoenix Mall, O 66/N 142, Velachery Road, Velachery, Chennai and the average cost for 2 would be INR 1     800\n7    3500\n2    1700\n5     800\n0    1200\n3    1200\n4     800\n6     500\n9     850\n8     450\nName: cost_for_2, dtype: int64. \nPedreno's with average rating of 4.1 found at 113/114, PS Sivaswami Salai, Mylapore, Chennai and the average cost for 2 would be INR 1     800\n7    3500\n2    1700\n5     800\n0    1200\n3    1200\n4     800\n6     500\n9     850\n8     450\nName: cost_for_2, dtype: int64. \nTuscana Pizzeria with average rating of 4.1 found at 19, 3rd Street, Wallace Garden Road, Nungambakkam, Chennai and the average cost for 2 would be INR 1     800\n7    3500\n2    1700\n5     800\n0    1200\n3    1200\n4     800\n6     500\n9     850\n8     450\nName: cost_for_2, dtype: int64. \nTryst Cafe with average rating of 4.1 found at 4/359, Gatsby Village, East Coast Road, Neelangarai, Chennai and the average cost for 2 would be INR 1     800\n7    3500\n2    1700\n5     800\n0    1200\n3    1200\n4     800\n6     500\n9     850\n8     450\nName: cost_for_2, dtype: int64. \nKalo's with average rating of 4.0 found at Shop 8, Thiruvalluvar Nagar, Besant Nagar, Chennai and the average cost for 2 would be INR 1     800\n7    3500\n2    1700\n5     800\n0    1200\n3    1200\n4     800\n6     500\n9     850\n8     450\nName: cost_for_2, dtype: int64. \nOx & Tomato with average rating of 4.0 found at 2/15, Ganapathy Colony, Main Road, Near Bank of Baroda ATM, Sri Ram Nagar, Teynampet, Chennai and the average cost for 2 would be INR 1     800\n7    3500\n2    1700\n5     800\n0    1200\n3    1200\n4     800\n6     500\n9     850\n8     450\nName: cost_for_2, dtype: int64. \nMidnight Madness with average rating of 3.7 found at 1/1, F-3, 1st Floor, Sindhuja Complex, 29th Cross Street, Indira Nagar, Adyar, Chennai and the average cost for 2 would be INR 1     800\n7    3500\n2    1700\n5     800\n0    1200\n3    1200\n4     800\n6     500\n9     850\n8     450\nName: cost_for_2, dtype: int64. \n"

# %%
s = 'aaalkjsdf;ljsD;lgfj;lSDJFGL:jdf;lgjl;dfjgl;dJgl;jdfl;gjdfl;gjl;dfjg;ldfjgl;jdgjdf;ljgl;DFJgl;jd;lgjdfl;gjl;dfjgl;dfjgl;jdfl;gjdfl;gjl;dzfjgl;dfjg;jkdf;gjdf;ljg;dfjg;dfj;'

# %%
s
# Out:
# 'aaalkjsdf;ljsD;lgfj;lSDJFGL:jdf;lgjl;dfjgl;dJgl;jdfl;gjdfl;gjl;dfjg;ldfjgl;jdgjdf;ljgl;DFJgl;jd;lgjdfl;gjl;dfjgl;dfjgl;jdfl;gjdfl;gjl;dzfjgl;dfjg;jkdf;gjdf;ljg;dfjg;dfj;'

# %%
city = ['Ahmedabad', 'Bengaluru', 'Bangalore', 'Chennai', 'Madras', 'Delhi', 'New Delhi', 'Hyderabad', 'Kolkata', 'Calcutta', 'Mumbai', 'Bombay', 'Pune',
					'Agra', 'Ajmer', 'Aligarh', 'Amravati', 'Amritsar', 'Asansol', 'Aurangabad', 'Bareilly', 'Belgaum', 'Bhavnagar', 'Bhiwandi', 'Bhopal', 'Bhubaneswar', 
					'Bikaner', 'Bilaspur', 'Bokaro Steel City', 'Chandigarh', 'Coimbatore', 'Cuttack', 'Dehradun', 'Dhanbad', 'Bhilai', 'Durgapur', 'Dindigul', 'Erode', 
					'Faridabad', 'Firozabad', 'Ghaziabad', 'Gorakhpur', 'Gulbarga', 'Guntur', 'Gwalior', 'Gurgaon', 'Guwahati', 'Hamirpur', 'Hubli–Dharwad', 'Indore', 
					'Jabalpur', 'Jaipur', 'Jalandhar', 'Jammu', 'Jamnagar', 'Jamshedpur', 'Jhansi', 'Jodhpur', 'Kakinada', 'Kannur', 'Kanpur', 'Karnal', 'Kochi', 
					'Kolhapur', 'Kollam', 'Kozhikode', 'Kurnool', 'Ludhiana', 'Lucknow', 'Madurai', 'Malappuram', 'Mathura', 'Mangalore', 'Meerut', 'Moradabad', 
					'Mysore', 'Nagpur', 'Nanded', 'Nashik', 'Nellore', 'Noida', 'Patna', 'Pondicherry', 'Purulia', 'Prayagraj', 'Raipur', 'Rajkot', 'Rajahmundry', 
					'Ranchi', 'Rourkela', 'Salem', 'Sangli', 'Shimla', 'Siliguri', 'Solapur', 'Srinagar', 'Surat', 'Thanjavur', 'Thiruvananthapuram', 'Thrissur', 
					'Tiruchirappalli', 'Tirunelveli', 'Ujjain', 'Bijapur', 'Vadodara', 'Varanasi', 'Vasai-Virar City', 'Vijayawada', 'Visakhapatnam', 'Vellore', 'Warangal']

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# %%
from_email = 'foodie.restaurantfinder@gmail.com'
to_email = 'sundararajan.n@gmail.com'
cred = 'Upgrad123'
gmail = smtplib.SMTP('smtp.gmail.com',587)
gmail.ehlo()
gmail.starttls()
gmail.login(from_email, cred)
email_subject = 'Hello from Foodie'
email_msg = MIMEMultipart()
email_msg['From'] = from_email
email_msg['TO'] = to_email
email_msg['Subject'] = email_subject
email_body = response
email_msg.attach(MIMEText(email_body,'plain'))
email_text = email_msg.as_string()
gmail.sendmail(from_email,to_email,email_text)
gmail.close()

# %%
import spacy
nlp = spacy.load('en_core_web_md')
# Out:
# less 7

# %%
test = nlp('find a less than 300 restaurant')
print(test[1].text, test[2].idx)
# Out:
# a 7

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import unicode_literals

from rasa_core_sdk.events import AllSlotsReset
from rasa_sdk import Action
from rasa_sdk.events import SlotSet
import zomatopy
import json

import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

import pandas as pd
import re

# %%
class SendEmail(Action):
	def name(self):
		return 'action_send_email'

	def checkmail(self, email):
		#complete the function
		#the function should return the strings "invalid" or "valid" based on the email ID entered
		email_regex = re.compile('^[a-zA-Z0-9-_]+(\.[a-zA-Z0-9-_])*@[a-z]+\.[a-z]{2,3}$')
		valid = email_regex.match(email)
		if valid == None:
			return 'invalid'
		else:
			return 'valid'
	def run(self, dispatcher, tracker, domain):
		from_email = 'foodie.restaurantfinder@gmail.com'
		to_email = tracker.get_slot('email')
		#to_email = 'sundararajan.n@gmail.com'
		if checkmail(self, to_email) == 'valid':
			tracker.slots['email_chk'] = 'valid'
			cred = 'Upgrad123'
			gmail = smtplib.SMTP('smtp.gmail.com',587)
			gmail.ehlo()
			gmail.starttls()
			gmail.login(from_email, cred)
			email_subject = 'Hello from Foodie'
			email_msg = MIMEMultipart()
			email_msg['From'] = from_email
			email_msg['TO'] = to_email
			email_msg['Subject'] = email_subject
			email_body = 'Test Email Body'
			email_msg.attach(MIMEText(email_body,'plain'))
			email_text = email_msg.as_string()
			gmail.sendmail(from_email,to_email,email_text)
			gmail.close()
			return[AllSlotsReset()]
		else:
			return[SlotSet('email_chk','invalid')]

class ActionChatReset(Action): 
	def name(self): 
		return 'action_reset_chat' 
	def run(self, dispatcher, tracker, domain): 
		return[AllSlotsReset()]
