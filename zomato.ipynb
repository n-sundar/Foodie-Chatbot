# %%
import requests
import json
import pandas as pd

# %%
base_url = "https://developers.zomato.com/api/v2.1/"
headers = {'Accept': 'application/json', 'user-key': '7c5b4cda151a68ab847143b592e4c232'}
r = (requests.get(base_url + "locations?query=" + str('hyderabad') + "&count=" + str(5), headers=headers).content).decode("utf-8")
json.loads(r)
# Out:
# {'location_suggestions': [{'entity_type': 'city',
#    'entity_id': 6,
#    'title': 'Hyderabad',
#    'latitude': 17.366,
#    'longitude': 78.476,
#    'city_id': 6,
#    'city_name': 'Hyderabad',
#    'country_id': 1,
#    'country_name': 'India'},
#   {'entity_type': 'zone',
#    'entity_id': 7000,
#    'title': 'Hyderabad City, Hyderabad',
#    'latitude': 17.415839,
#    'longitude': 78.438349,
#    'city_id': 6,
#    'city_name': 'Hyderabad',
#    'country_id': 1,
#    'country_name': 'India'},
#   {'entity_type': 'group',
#    'entity_id': 4678,
#    'title': 'Hyderabad Central Mall, Panjagutta , Hyderabad',
#    'latitude': 17.4269562613,
#    'longitude': 78.4528752789,
#    'city_id': 6,
#    'city_name': 'Hyderabad',
#    'country_id': 1,
#    'country_name': 'India'},
#   {'entity_type': 'group',
#    'entity_id': 40191,
#    'title': 'Hyderabad Marriott Hotel & Convention Centre, Hyderabad',
#    'latitude': 17.4252582943,
#    'longitude': 78.4869799018,
#    'city_id': 6,
#    'city_name': 'Hyderabad',
#    'country_id': 1,
#    'country_name': 'India'},
#   {'entity_type': 'zone',
#    'entity_id': 110448,
#    'title': 'Patancheru City, Hyderabad',
#    'latitude': 17.528751,
#    'longitude': 78.266812,
#    'city_id': 6,
#    'city_name': 'Hyderabad',
#    'country_id': 1,
#    'country_name': 'India'}],
#  'status': 'success',
#  'has_more': 0,
#  'has_total': 0,
#  'user_has_addresses': True}

# %%
location_json = json.loads(r)
location_results = len(location_json['location_suggestions'])
lat=location_json["location_suggestions"][0]["latitude"]
lon=location_json["location_suggestions"][0]["longitude"]
city_id=location_json["location_suggestions"][0]["city_id"]
print(location_results,lat,lon,city_id)
# Out:
# 5 17.366 78.476 6

# %%
cuisines_dict={'american': 1,'chinese': 25, 'north indian': 50, 'italian': 55, 'mexican': 73, 'south indian': 85, 'thai': 95}
cuisines = str(cuisines_dict['south indian'])

cuisines = "%2C".join(cuisines.split(","))
headers = {'Accept': 'application/json', 'user-key': '7c5b4cda151a68ab847143b592e4c232'}
r = (requests.get(base_url + "search?q=" + str('') + "&count=" + str(10) + "&lat=" + str(lat) + "&lon=" + str(lon) + "&cuisines=" + str(cuisines), headers=headers).content).decode("utf-8")

# %%
json.loads(r)
# Out:
# {'results_found': 2560,
#  'results_start': 0,
#  'results_shown': 10,
#  'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': 0,
#       'takeaway': -1},
#      'res_id': 18752268,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '18752268',
#     'name': 'Subbayya Gari Hotel',
#     'url': 'https://www.zomato.com/hyderabad/subbayya-gari-hotel-kukatpally?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'MIG 295, Sri Devi Residency, Road 4, KPHB Colony, Kukatpally, Hyderabad',
#      'locality': 'Kukatpally',
#      'city': 'Hyderabad',
#      'city_id': 6,
#      'latitude': '17.4901063300',
#      'longitude': '78.3965562657',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Kukatpally, Hyderabad'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian, Andhra',
#     'timings': '10 AM to 11 PM',
#     'average_cost_for_two': 400,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Credit Card',
#      'Lunch',
#      'Takeaway Available',
#      'Delivery',
#      'Debit Card',
#      'Cash',
#      'Breakfast',
#      'Indoor Seating',
#      'Digital Payments Accepted',
#      'Air Conditioned',
#      'Group Meal'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/8/18752268/6d39c2cfa97dbbdc0354dd17db3ea66c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.2',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.2'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 5478},
#     'all_reviews_count': 538,
#     'photos_url': 'https://www.zomato.com/hyderabad/subbayya-gari-hotel-kukatpally/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 91,
#     'menu_url': 'https://www.zomato.com/hyderabad/subbayya-gari-hotel-kukatpally/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/8/18752268/6d39c2cfa97dbbdc0354dd17db3ea66c.jpg',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18752268',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/hyderabad/subbayya-gari-hotel-kukatpally/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9010888842, +91 9010888843',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 92651,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '92651',
#     'name': 'Ram Ki Bandi',
#     'url': 'https://www.zomato.com/hyderabad/ram-ki-bandi-nampally?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Opposite Karachi Bakery, Mozamjahi Market, Nampally, Hyderabad',
#      'locality': 'Nampally',
#      'city': 'Hyderabad',
#      'city_id': 6,
#      'latitude': '17.3834839121',
#      'longitude': '78.4753739834',
#      'zipcode': '0',
#      'country_id': 1,
#      'locality_verbose': 'Nampally, Hyderabad'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '5 AM to 8 AM',
#     'average_cost_for_two': 150,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Takeaway Available',
#      'Cash',
#      'Delivery',
#      'Breakfast',
#      'No Seating Available',
#      'Pure Veg'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/92651_RESTAURANT_d19524b28108da2a8cebc9744aef5197.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.3',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.3'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 5875},
#     'all_reviews_count': 896,
#     'photos_url': 'https://www.zomato.com/hyderabad/ram-ki-bandi-nampally/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 269,
#     'menu_url': 'https://www.zomato.com/hyderabad/ram-ki-bandi-nampally/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/92651_RESTAURANT_d19524b28108da2a8cebc9744aef5197.jpg',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/92651',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/hyderabad/ram-ki-bandi-nampally/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9963968082',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Kiosk'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 97398,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '97398',
#     'name': 'House of Dosas',
#     'url': 'https://www.zomato.com/hyderabad/house-of-dosas-banjara-hills?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Opposite Lucid Diagnostics, Road 2, Banjara Hills, Hyderabad',
#      'locality': 'Banjara Hills',
#      'city': 'Hyderabad',
#      'city_id': 6,
#      'latitude': '17.4234150801',
#      'longitude': '78.4291571751',
#      'zipcode': '500034',
#      'country_id': 1,
#      'locality_verbose': 'Banjara Hills, Hyderabad'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '7:30 AM to 1 AM',
#     'average_cost_for_two': 300,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Breakfast',
#      'Takeaway Available',
#      'Cash',
#      'Lunch',
#      'Credit Card',
#      'Delivery',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Pure Veg'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/8/97398/23ff5b3431ab4bec4cc4f529708e7a9f.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.3',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.3'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 4986},
#     'all_reviews_count': 643,
#     'photos_url': 'https://www.zomato.com/hyderabad/house-of-dosas-banjara-hills/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 842,
#     'menu_url': 'https://www.zomato.com/hyderabad/house-of-dosas-banjara-hills/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/8/97398/23ff5b3431ab4bec4cc4f529708e7a9f.jpg?output-format=webp',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/97398',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/hyderabad/house-of-dosas-banjara-hills/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 8978495894',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 19113172,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '19113172',
#     'name': 'Subbaiah Gari Hotel',
#     'url': 'https://www.zomato.com/hyderabad/subbaiah-gari-hotel-malakpet?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '16-10-1/S/47, A, B, C, D, E & F, Upper Ground Floor, Sri Krupa Market, Mahaboob Mansion, Malakpet, Hyderabad',
#      'locality': 'Malakpet',
#      'city': 'Hyderabad',
#      'city_id': 6,
#      'latitude': '17.3730614642',
#      'longitude': '78.5072657838',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Malakpet, Hyderabad'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian, Andhra',
#     'timings': '11 AM to 5 PM, 7:30 PM to 11 PM',
#     'average_cost_for_two': 400,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Delivery',
#      'Credit Card',
#      'Lunch',
#      'Cash',
#      'Takeaway Available',
#      'Debit Card',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Digital Payments Accepted'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/8/18752268/6d39c2cfa97dbbdc0354dd17db3ea66c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.2',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.2'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 18441},
#     'all_reviews_count': 183,
#     'photos_url': 'https://www.zomato.com/hyderabad/subbaiah-gari-hotel-malakpet/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 20,
#     'menu_url': 'https://www.zomato.com/hyderabad/subbaiah-gari-hotel-malakpet/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/8/18752268/6d39c2cfa97dbbdc0354dd17db3ea66c.jpg?output-format=webp',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/19113172',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/hyderabad/subbaiah-gari-hotel-malakpet/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 8333866123',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 1, 'takeaway': -1},
#      'res_id': 18715296,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '18715296',
#     'name': 'Bakasura Restaurant',
#     'url': 'https://www.zomato.com/hyderabad/bakasura-restaurant-as-rao-nagar-secunderabad?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '11-6-9/C, 1st & 2nd Floor, Radhika Lane, A S Rao Nagar, Secunderabad',
#      'locality': 'A S Rao Nagar',
#      'city': 'Secunderabad',
#      'city_id': 6,
#      'latitude': '17.4750532145',
#      'longitude': '78.5631080344',
#      'zipcode': '500062',
#      'country_id': 1,
#      'locality_verbose': 'A S Rao Nagar, Secunderabad'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Andhra, South Indian',
#     'timings': '11am – 11:30pm (Mon-Sun)',
#     'average_cost_for_two': 800,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Delivery',
#      'Credit Card',
#      'Lunch',
#      'Cash',
#      'Takeaway Available',
#      'Debit Card',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Free Wifi'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/6/18715296/0e214eb7bdfa301ed2f8f2824e821a54.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.0',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.0'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 26891},
#     'all_reviews_count': 335,
#     'photos_url': 'https://www.zomato.com/hyderabad/bakasura-restaurant-as-rao-nagar-secunderabad/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 375,
#     'menu_url': 'https://www.zomato.com/hyderabad/bakasura-restaurant-as-rao-nagar-secunderabad/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/6/18715296/0e214eb7bdfa301ed2f8f2824e821a54.jpg',
#     'medio_provider': 1,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18715296',
#     'order_url': 'https://www.zomato.com/hyderabad/bakasura-restaurant-as-rao-nagar-secunderabad/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 1,
#     'has_table_booking': 1,
#     'book_url': 'https://www.zomato.com/hyderabad/bakasura-restaurant-as-rao-nagar-secunderabad/book?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'events_url': 'https://www.zomato.com/hyderabad/bakasura-restaurant-as-rao-nagar-secunderabad/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '040 27122727, 040 27132727',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 92652,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '92652',
#     'name': 'Govind Dosa',
#     'url': 'https://www.zomato.com/hyderabad/govind-dosa-charminar?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Gulzar Hauz, Charminar, Hyderabad',
#      'locality': 'Charminar',
#      'city': 'Hyderabad',
#      'city_id': 6,
#      'latitude': '17.3641721733',
#      'longitude': '78.4738035500',
#      'zipcode': '0',
#      'country_id': 1,
#      'locality_verbose': 'Charminar, Hyderabad'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '6:30 AM to 3 PM',
#     'average_cost_for_two': 300,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Cash',
#      'Takeaway Available',
#      'Credit Card',
#      'Lunch',
#      'Delivery',
#      'Breakfast',
#      'Indoor Seating',
#      'Pure Veg'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/2/92652/eec704e8a401bb0b222ce239e2d037bb.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.1',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.1'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 3188},
#     'all_reviews_count': 293,
#     'photos_url': 'https://www.zomato.com/hyderabad/govind-dosa-charminar/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 182,
#     'menu_url': 'https://www.zomato.com/hyderabad/govind-dosa-charminar/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/2/92652/eec704e8a401bb0b222ce239e2d037bb.jpg',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/92652',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/hyderabad/govind-dosa-charminar/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9246522078',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 92738,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '92738',
#     'name': 'Pragati Tiffin Center',
#     'url': 'https://www.zomato.com/hyderabad/pragati-tiffin-center-koti?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'H V S Road, Hanuman Tekdi, Near Pargati College, Koti, Hyderabad',
#      'locality': 'Koti',
#      'city': 'Hyderabad',
#      'city_id': 6,
#      'latitude': '17.3881303541',
#      'longitude': '78.4812704846',
#      'zipcode': '0',
#      'country_id': 1,
#      'locality_verbose': 'Koti, Hyderabad'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '6:30 AM to 9 PM',
#     'average_cost_for_two': 150,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Takeaway Available',
#      'Breakfast',
#      'Lunch',
#      'Cash',
#      'Indoor Seating',
#      'Pure Veg'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/8/92738/bc7b88c6079d4b94cbe8e1f6b9d5a218.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.5',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'rating_obj': {'title': {'text': '4.5'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 1503},
#     'all_reviews_count': 359,
#     'photos_url': 'https://www.zomato.com/hyderabad/pragati-tiffin-center-koti/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 192,
#     'menu_url': 'https://www.zomato.com/hyderabad/pragati-tiffin-center-koti/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/8/92738/bc7b88c6079d4b94cbe8e1f6b9d5a218.jpg?output-format=webp',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/92738',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/hyderabad/pragati-tiffin-center-koti/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9866875408',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 1, 'takeaway': -1},
#      'res_id': 94160,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '94160',
#     'name': 'Lakshmi Tiffin Centre',
#     'url': 'https://www.zomato.com/hyderabad/lakshmi-tiffin-centre-madhapur?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Ayyappa Society, Near YSR Statue, Madhapur, Hyderabad',
#      'locality': 'Madhapur',
#      'city': 'Hyderabad',
#      'city_id': 6,
#      'latitude': '17.4511740000',
#      'longitude': '78.3917390000',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Madhapur, Hyderabad'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '7 AM to 10:30 PM (Mon-Sat), 7 AM to 12 Noon (Sun)',
#     'average_cost_for_two': 200,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Lunch',
#      'Cash',
#      'Takeaway Available',
#      'Dinner',
#      'Delivery',
#      'Outdoor Seating',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/0/94160/bfaf1ef5db7879f5fcc86b8158f3b4bf.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.1',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.1'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 40527},
#     'all_reviews_count': 314,
#     'photos_url': 'https://www.zomato.com/hyderabad/lakshmi-tiffin-centre-madhapur/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 24,
#     'menu_url': 'https://www.zomato.com/hyderabad/lakshmi-tiffin-centre-madhapur/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/0/94160/bfaf1ef5db7879f5fcc86b8158f3b4bf.jpg',
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/94160',
#     'order_url': 'https://www.zomato.com/hyderabad/lakshmi-tiffin-centre-madhapur/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/hyderabad/lakshmi-tiffin-centre-madhapur/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9063772771',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 1, 'takeaway': -1},
#      'res_id': 96750,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '96750',
#     'name': 'Krupa Mess & Tiffins',
#     'url': 'https://www.zomato.com/hyderabad/krupa-mess-tiffins-abids?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '4-1-827/3, Beside Ramakrishna Theater, Abids, Hyderabad',
#      'locality': 'Abids',
#      'city': 'Hyderabad',
#      'city_id': 6,
#      'latitude': '17.3864057898',
#      'longitude': '78.4762289375',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Abids, Hyderabad'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '10 AM to 11 PM',
#     'average_cost_for_two': 250,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Lunch',
#      'Credit Card',
#      'Delivery',
#      'Takeaway Available',
#      'Cash',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/6/19224746/020e5f88883540bbae8ed766a47aff87.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '3.9',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.9'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 26094},
#     'all_reviews_count': 564,
#     'photos_url': 'https://www.zomato.com/hyderabad/krupa-mess-tiffins-abids/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 201,
#     'menu_url': 'https://www.zomato.com/hyderabad/krupa-mess-tiffins-abids/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/6/19224746/020e5f88883540bbae8ed766a47aff87.jpg',
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/96750',
#     'order_url': 'https://www.zomato.com/hyderabad/krupa-mess-tiffins-abids/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/hyderabad/krupa-mess-tiffins-abids/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '040 66666866',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Mess'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 19105349,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '19105349',
#     'name': 'Subbayya Gari Hotel',
#     'url': 'https://www.zomato.com/hyderabad/subbayya-gari-hotel-kondapur?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Plot 712, Survey 11/1, House 2-17/89/Ep/101, Door 2-17/89/Ep/101, First Floor, Ektha Pearl, Kondapur, Hyderabad',
#      'locality': 'Kondapur',
#      'city': 'Hyderabad',
#      'city_id': 6,
#      'latitude': '17.4561080945',
#      'longitude': '78.3650460094',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Kondapur, Hyderabad'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '12noon – 4pm, 7pm – 10:30pm (Mon-Sun)',
#     'average_cost_for_two': 400,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Delivery',
#      'Credit Card',
#      'Lunch',
#      'Cash',
#      'Takeaway Available',
#      'Debit Card',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Digital Payments Accepted'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/8/18752268/6d39c2cfa97dbbdc0354dd17db3ea66c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '3.9',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.9'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 1424},
#     'all_reviews_count': 279,
#     'photos_url': 'https://www.zomato.com/hyderabad/subbayya-gari-hotel-kondapur/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 32,
#     'menu_url': 'https://www.zomato.com/hyderabad/subbayya-gari-hotel-kondapur/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/8/18752268/6d39c2cfa97dbbdc0354dd17db3ea66c.jpg?output-format=webp',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/19105349',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/hyderabad/subbayya-gari-hotel-kondapur/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9988993366',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}}]}

# %%
d1 = json.loads(r)
print(type(d1))
d = d1['restaurants']
print(type(d))
df1 = pd.DataFrame([{'restaurant_name': x['restaurant']['name'], 'restaurant_rating': x['restaurant']['user_rating']['aggregate_rating'],
'restaurant_address': x['restaurant']['location']['address'],'budget_for2people': x['restaurant']['average_cost_for_two'],
'restaurant_photo': x['restaurant']['featured_image'], 'restaurant_url': x['restaurant']['url'] } for x in d])
# Out:
# <class 'dict'>
# <class 'list'>

# %%
df1
# Out:
#               restaurant_name restaurant_rating  \
# 0        Saleem Punjabi Dhaba               3.8
# 1         Tara Maa Restaurant               3.9
# 2                Yaseen Dhaba               3.6
# 3      Rajshree Punjabi Dhaba               3.8
# 4        Saleem Punjabi Dhaba               4.0
# 5      UBQ By Barbeque Nation               3.5
# 6               Punjabi Dhaba               3.6
# 7             Behrouz Biryani               4.0
# 8       Rajshree Mithai Chats               3.1
# 9  Hyderabad Tandoori Chicken               3.8
#
#                                   restaurant_address  budget_for2people  \
# 0        Opposite to VIT Main Gate, Katpadi, Vellore                350
# 1  VIT Main Gate, Kangeyanallore Road, Katpadi, V...                200
# 2  VIT Main Gate, Kangeyanallore Road, Katpadi, V...                300
# 3  14/1 Post Office Street, Opposite to Venus The...                200
# 4  VIT Main Gate, Kangeyanallore Road, Katpadi, V...                250
# 5  16/1, Survey T.S. 316, 316/4B3, First Floor, O...                400
# 6       VIT College, VIT Main Road, Katpadi, Vellore                300
# 7  10, Andal Nagar, Thiruvalam Road, Katpadi, Vel...                700
# 8  Shop 23, Vellaikalmedu, Kangeyanallur Road, VI...                200
# 9  Bangalore To Chennai Highway, Green Circle, Th...                200
#
#                                     restaurant_photo  \
# 0
# 1
# 2
# 3
# 4
# 5  https://b.zmtcdn.com/data/pictures/9/18995459/...
# 6
# 7  https://b.zmtcdn.com/data/pictures/chains/9/19...
# 8
# 9
#
#                                       restaurant_url
# 0  https://www.zomato.com/vellore/saleem-punjabi-...
# 1  https://www.zomato.com/vellore/tara-maa-restau...
# 2  https://www.zomato.com/vellore/yaseen-dhaba-ka...
# 3  https://www.zomato.com/vellore/rajshree-punjab...
# 4  https://www.zomato.com/vellore/saleem-punjabi-...
# 5  https://www.zomato.com/vellore/ubq-by-barbeque...
# 6  https://www.zomato.com/vellore/punjabi-dhaba-k...
# 7  https://www.zomato.com/vellore/behrouz-biryani...
# 8  https://www.zomato.com/vellore/rajshree-mithai...
# 9  https://www.zomato.com/vellore/hyderabad-tando...

# %%
city = ['Ahmedabad', 'Bengaluru', 'Bangalore', 'Chennai', 'Madras', 'Delhi', 'New Delhi', 'Hyderabad', 'Kolkata', 'Calcutta', 'Mumbai', 'Bombay', 'Pune',
					'Agra', 'Ajmer', 'Aligarh', 'Amravati', 'Amritsar', 'Asansol', 'Aurangabad', 'Bareilly', 'Belgaum', 'Bhavnagar', 'Bhiwandi', 'Bhopal', 'Bhubaneswar', 
					'Bikaner', 'Bilaspur', 'Bokaro Steel City', 'Chandigarh', 'Coimbatore', 'Cuttack', 'Dehradun', 'Dhanbad', 'Bhilai', 'Durgapur', 'Dindigul', 'Erode', 
					'Faridabad', 'Firozabad', 'Ghaziabad', 'Gorakhpur', 'Gulbarga', 'Guntur', 'Gwalior', 'Gurgaon', 'Guwahati', 'Hamirpur', 'Hubli–Dharwad', 'Indore', 
					'Jabalpur', 'Jaipur', 'Jalandhar', 'Jammu', 'Jamnagar', 'Jamshedpur', 'Jhansi', 'Jodhpur', 'Kakinada', 'Kannur', 'Kanpur', 'Karnal', 'Kochi', 
					'Kolhapur', 'Kollam', 'Kozhikode', 'Kurnool', 'Ludhiana', 'Lucknow', 'Madurai', 'Malappuram', 'Mathura', 'Mangalore', 'Meerut', 'Moradabad', 
					'Mysore', 'Nagpur', 'Nanded', 'Nashik', 'Nellore', 'Noida', 'Patna', 'Pondicherry', 'Purulia', 'Prayagraj', 'Raipur', 'Rajkot', 'Rajahmundry', 
					'Ranchi', 'Rourkela', 'Salem', 'Sangli', 'Shimla', 'Siliguri', 'Solapur', 'Srinagar', 'Surat', 'Thanjavur', 'Thiruvananthapuram', 'Thrissur', 
					'Tiruchirappalli', 'Tirunelveli', 'Ujjain', 'Bijapur', 'Vadodara', 'Varanasi', 'Vasai-Virar City', 'Vijayawada', 'Visakhapatnam', 'Vellore', 'Warangal']

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# %%
from_email = 'foodie.restaurantfinder@gmail.com'
to_email = 'sundararajan.n@gmail.com'
cred = 'Upgrad123'
gmail = smtplib.SMTP('smtp.gmail.com',587)
gmail.ehlo()
gmail.starttls()
gmail.login(from_email, cred)
email_subject = 'Hello from Foodie'
email_msg = MIMEMultipart()
email_msg['From'] = from_email
email_msg['TO'] = to_email
email_msg['Subject'] = email_subject
email_body = 'Test Email Body'
email_msg.attach(MIMEText(email_body,'plain'))
email_text = email_msg.as_string()
gmail.sendmail(from_email,to_email,email_text)
gmail.close()
