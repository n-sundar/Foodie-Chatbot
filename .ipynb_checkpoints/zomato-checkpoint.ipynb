# %%
import requests
import json
import pandas as pd

# %%
base_url = "https://developers.zomato.com/api/v2.1/"
headers = {'Accept': 'application/json', 'user-key': '7c5b4cda151a68ab847143b592e4c232'}
r = (requests.get(base_url + "locations?query=" + str('chennai') + "&count=" + str(5), headers=headers).content).decode("utf-8")
json.loads(r)
# Out:
# {'location_suggestions': [{'entity_type': 'city',
#    'entity_id': 7,
#    'title': 'Chennai',
#    'latitude': 13.083889,
#    'longitude': 80.27,
#    'city_id': 7,
#    'city_name': 'Chennai',
#    'country_id': 1,
#    'country_name': 'India'},
#   {'entity_type': 'group',
#    'entity_id': 1560,
#    'title': 'Chennai Citi Centre, Mylapore, Chennai',
#    'latitude': 13.0431049226,
#    'longitude': 80.2739004046,
#    'city_id': 7,
#    'city_name': 'Chennai',
#    'country_id': 1,
#    'country_name': 'India'},
#   {'entity_type': 'group',
#    'entity_id': 42478,
#    'title': 'Chennai Food Town, Thuraipakkam, Chennai',
#    'latitude': 12.9752851053,
#    'longitude': 80.2440279722,
#    'city_id': 7,
#    'city_name': 'Chennai',
#    'country_id': 1,
#    'country_name': 'India'},
#   {'entity_type': 'zomato_place',
#    'entity_id': 109166,
#    'title': 'Chennai Theni Highway, Urapakkam, Chennai',
#    'latitude': 12.861058406452,
#    'longitude': 80.072705545161,
#    'city_id': 7,
#    'city_name': 'Chennai',
#    'country_id': 1,
#    'country_name': 'India'},
#   {'entity_type': 'zomato_place',
#    'entity_id': 109245,
#    'title': 'Chennai Tiruvallur High Road, Padi, Chennai',
#    'latitude': 13.100079,
#    'longitude': 80.189263425,
#    'city_id': 7,
#    'city_name': 'Chennai',
#    'country_id': 1,
#    'country_name': 'India'}],
#  'status': 'success',
#  'has_more': 0,
#  'has_total': 0,
#  'user_has_addresses': True}

# %%
location_json = json.loads(r)
location_results = len(location_json['location_suggestions'])
lat=location_json["location_suggestions"][0]["latitude"]
lon=location_json["location_suggestions"][0]["longitude"]
city_id=location_json["location_suggestions"][0]["city_id"]
print(location_results,lat,lon,city_id)
# Out:
# 5 13.083889 80.27 7

# %%
cuisines_dict={'american': 1,'chinese': 25, 'north indian': 50, 'italian': 55, 'mexican': 73, 'south indian': 85, 'thai': 95}
cuisines = str(cuisines_dict['south indian'])

cuisines = "%2C".join(cuisines.split(","))
headers = {'Accept': 'application/json', 'user-key': '7c5b4cda151a68ab847143b592e4c232'}
r = (requests.get(base_url + "search?q=" + str('') + "&count=" + str(10) + "&lat=" + str(lat) + "&lon=" + str(lon) + "&cuisines=" + str(cuisines) + "&count=50" , headers=headers).content).decode("utf-8")

# %%
json.loads(r)
# Out:
# {'results_found': 4228,
#  'results_start': 0,
#  'results_shown': 20,
#  'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1,
#       'takeaway': -1},
#      'res_id': 70961,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '70961',
#     'name': 'Prems Graama Bhojanam',
#     'url': 'https://www.zomato.com/chennai/prems-graama-bhojanam-adyar?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '23/10, 3rd Main Road, Kasturba Nagar, Adyar, Chennai',
#      'locality': 'Adyar',
#      'city': 'Chennai',
#      'city_id': 7,
#      'latitude': '13.0048579613',
#      'longitude': '80.2527022362',
#      'zipcode': '600020',
#      'country_id': 1,
#      'locality_verbose': 'Adyar, Chennai'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '12noon – 3pm, 7pm – 10pm (Mon-Sun)',
#     'average_cost_for_two': 500,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Cash',
#      'Takeaway Available',
#      'Credit Card',
#      'Lunch',
#      'Delivery',
#      'Debit Card',
#      'Indoor Seating',
#      'Pure Veg',
#      'Digital Payments Accepted',
#      'Gluten Free Options',
#      'Vegan Options'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/70961_RESTAURANT_393fc340046d94077802b606508c2401.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.6',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'rating_obj': {'title': {'text': '4.6'},
#       'bg_color': {'type': 'lime', 'tint': '800'}},
#      'votes': 6134},
#     'all_reviews_count': 871,
#     'photos_url': 'https://www.zomato.com/chennai/prems-graama-bhojanam-adyar/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 910,
#     'menu_url': 'https://www.zomato.com/chennai/prems-graama-bhojanam-adyar/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/70961_RESTAURANT_393fc340046d94077802b606508c2401.jpg',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/70961',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/chennai/prems-graama-bhojanam-adyar/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9840062772, +91 9940108852, 044 43362277',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 18675220,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '18675220',
#     'name': 'Eating Circles',
#     'url': 'https://www.zomato.com/chennai/eating-circles-alwarpet?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '6, CP Ramaswamy Road, Alwarpet, Chennai',
#      'locality': 'Alwarpet',
#      'city': 'Chennai',
#      'city_id': 7,
#      'latitude': '13.0303887117',
#      'longitude': '80.2562605217',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Alwarpet, Chennai'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '7 AM to 11 PM',
#     'average_cost_for_two': 250,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Cash',
#      'Takeaway Available',
#      'Credit Card',
#      'Debit Card',
#      'Lunch',
#      'Delivery',
#      'Breakfast',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Pure Veg'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/chains/7/18475417/a000933a8dd38e5b71d905af227a2109.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.4'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 4363},
#     'all_reviews_count': 351,
#     'photos_url': 'https://www.zomato.com/chennai/eating-circles-alwarpet/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 569,
#     'menu_url': 'https://www.zomato.com/chennai/eating-circles-alwarpet/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/7/18475417/a000933a8dd38e5b71d905af227a2109.jpg?output-format=webp',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18675220',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/chennai/eating-circles-alwarpet/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '044 48551117',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 67453,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '67453',
#     'name': "Rayar's Mess",
#     'url': 'https://www.zomato.com/chennai/rayars-mess-mylapore?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '31, Arundale Street, Mylapore, Chennai',
#      'locality': 'Mylapore',
#      'city': 'Chennai',
#      'city_id': 7,
#      'latitude': '13.0354950686',
#      'longitude': '80.2730652317',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Mylapore, Chennai'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '7 AM to 10:30 AM, 3 PM to 6:30 PM (Mon-Sat), 7 AM to 10:30 AM (Sun)',
#     'average_cost_for_two': 100,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Cash',
#      'Takeaway Available',
#      'Breakfast',
#      'Dinner',
#      'Delivery',
#      'Indoor Seating',
#      'Pure Veg'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/3/67453/96eecf0085f7d835b39c7a9b66806b43.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.4'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 2653},
#     'all_reviews_count': 410,
#     'photos_url': 'https://www.zomato.com/chennai/rayars-mess-mylapore/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 159,
#     'menu_url': 'https://www.zomato.com/chennai/rayars-mess-mylapore/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/3/67453/96eecf0085f7d835b39c7a9b66806b43.jpg',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/67453',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/chennai/rayars-mess-mylapore/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9940425551',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Mess'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 1, 'takeaway': -1},
#      'res_id': 68853,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '68853',
#     'name': 'Andhikkadai',
#     'url': 'https://www.zomato.com/chennai/andhikkadai-velachery?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '20, Dhandeeswaram Main Road, Velachery, Chennai',
#      'locality': 'Velachery',
#      'city': 'Chennai',
#      'city_id': 7,
#      'latitude': '12.9823809385',
#      'longitude': '80.2248253673',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Velachery, Chennai'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '7am – 11am, 12noon – 3pm, 4pm – 10pm (Mon-Sun)',
#     'average_cost_for_two': 200,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Breakfast',
#      'Dinner',
#      'Delivery',
#      'Credit Card',
#      'Debit Card',
#      'Lunch',
#      'Cash',
#      'Takeaway Available',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Pure Veg',
#      'Digital Payments Accepted'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/3/68853/1192d190a75856c9bb8306f0b9f90d79.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.4'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 19362},
#     'all_reviews_count': 520,
#     'photos_url': 'https://www.zomato.com/chennai/andhikkadai-velachery/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 304,
#     'menu_url': 'https://www.zomato.com/chennai/andhikkadai-velachery/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/3/68853/1192d190a75856c9bb8306f0b9f90d79.jpg?output-format=webp',
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/68853',
#     'order_url': 'https://www.zomato.com/chennai/andhikkadai-velachery/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/chennai/andhikkadai-velachery/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 8122311234, 044 48540006, 044 22438080',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 18676922,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '18676922',
#     'name': 'Nellai Vairamaligai',
#     'url': 'https://www.zomato.com/chennai/nellai-vairamaligai-t-nagar?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '60, Thirumalai Pillai Road, Rama Kamath Puram, T. Nagar, Chennai',
#      'locality': 'T. Nagar',
#      'city': 'Chennai',
#      'city_id': 7,
#      'latitude': '13.0510434447',
#      'longitude': '80.2404324710',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'T. Nagar, Chennai'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '12noon – 9pm (Mon, Tue, Wed, Thu, Fri, Sun), 4pm – 9pm (Sat)',
#     'average_cost_for_two': 500,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'Credit Card',
#      'Dinner',
#      'Cash',
#      'Takeaway Available',
#      'Debit Card',
#      'Indoor Seating',
#      'Digital Payments Accepted',
#      'Table Reservation Not Required',
#      'Air Conditioned'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/2/18676922/38c5d8c28559404bf191c721a9cd6a59.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.2',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.2'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 11421},
#     'all_reviews_count': 193,
#     'photos_url': 'https://www.zomato.com/chennai/nellai-vairamaligai-t-nagar/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 138,
#     'menu_url': 'https://www.zomato.com/chennai/nellai-vairamaligai-t-nagar/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/2/18676922/38c5d8c28559404bf191c721a9cd6a59.jpg',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18676922',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/chennai/nellai-vairamaligai-t-nagar/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 7200358888, 044 43858888, +91 8682996160',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 72004,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '72004',
#     'name': 'Mana Andhra',
#     'url': 'https://www.zomato.com/chennai/mana-andhra-nungambakkam?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '18/24, Khader Nawaskhan Road, Nungambakkam, Chennai',
#      'locality': 'Nungambakkam',
#      'city': 'Chennai',
#      'city_id': 7,
#      'latitude': '13.0607218582',
#      'longitude': '80.2498450130',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Nungambakkam, Chennai'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Andhra, Hyderabadi, South Indian',
#     'timings': '12 Noon to 3:30 PM, 7 PM to 11:30 PM',
#     'average_cost_for_two': 600,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Credit Card',
#      'Lunch',
#      'Cash',
#      'Delivery',
#      'Debit Card',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Wifi',
#      'Table reservation required'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/72004_RESTAURANT_e82b187056ecf78a328de4205d57b8fa.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.1',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.1'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 1681},
#     'all_reviews_count': 329,
#     'photos_url': 'https://www.zomato.com/chennai/mana-andhra-nungambakkam/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 533,
#     'menu_url': 'https://www.zomato.com/chennai/mana-andhra-nungambakkam/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/72004_RESTAURANT_e82b187056ecf78a328de4205d57b8fa.jpg?output-format=webp',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/72004',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/chennai/mana-andhra-nungambakkam/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '044 42106860',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 18811014,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '18811014',
#     'name': 'That Mallu Joint',
#     'url': 'https://www.zomato.com/chennai/that-mallu-joint-t-nagar?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '2nd Floor, PMG Complex, GN Chetty Road, T. Nagar, Chennai',
#      'locality': 'T. Nagar',
#      'city': 'Chennai',
#      'city_id': 7,
#      'latitude': '13.0417138178',
#      'longitude': '80.2344380692',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'T. Nagar, Chennai'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian, Kerala',
#     'timings': '12 Noon – 4 PM, 7 PM – 11 PM',
#     'average_cost_for_two': 600,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Lunch',
#      'Cash',
#      'Credit Card',
#      'Dinner',
#      'Takeaway Available',
#      'Debit Card',
#      'Valet Parking Available',
#      'Table reservation required',
#      'Indoor Seating',
#      'Air Conditioned'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.4'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 503},
#     'all_reviews_count': 251,
#     'photos_url': 'https://www.zomato.com/chennai/that-mallu-joint-t-nagar/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 363,
#     'menu_url': 'https://www.zomato.com/chennai/that-mallu-joint-t-nagar/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18811014',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/chennai/that-mallu-joint-t-nagar/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9551664958',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 1, 'takeaway': -1},
#      'res_id': 18650348,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '18650348',
#     'name': 'Savya Rasa',
#     'url': 'https://www.zomato.com/chennai/savya-rasa-kotturpuram?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '2/10, Gandhi Mandapam Road, Kotturpuram, Chennai',
#      'locality': 'Kotturpuram',
#      'city': 'Chennai',
#      'city_id': 7,
#      'latitude': '13.0188977986',
#      'longitude': '80.2411395684',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Kotturpuram, Chennai'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Chettinad, Andhra, Kerala, Mangalorean, South Indian',
#     'timings': '12 Noon to 9 PM',
#     'average_cost_for_two': 1600,
#     'price_range': 3,
#     'currency': 'Rs.',
#     'highlights': ['No Alcohol Available',
#      'Lunch',
#      'Dinner',
#      'Cash',
#      'Delivery',
#      'Takeaway Available',
#      'Credit Card',
#      'Debit Card',
#      'Indoor Seating',
#      'Table booking recommended',
#      'Free Parking',
#      'Air Conditioned',
#      'Gourmet'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/8/18650348/9e12a029c3eedd70a782c5a23c845e62.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.4'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 627},
#     'all_reviews_count': 205,
#     'photos_url': 'https://www.zomato.com/chennai/savya-rasa-kotturpuram/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 378,
#     'menu_url': 'https://www.zomato.com/chennai/savya-rasa-kotturpuram/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/8/18650348/9e12a029c3eedd70a782c5a23c845e62.jpg',
#     'medio_provider': 1,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18650348',
#     'order_url': 'https://www.zomato.com/chennai/savya-rasa-kotturpuram/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 1,
#     'has_table_booking': 1,
#     'book_url': 'https://www.zomato.com/chennai/savya-rasa-kotturpuram/book?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'events_url': 'https://www.zomato.com/chennai/savya-rasa-kotturpuram/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 7397774856',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Fine Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 1, 'takeaway': -1},
#      'res_id': 65381,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '65381',
#     'name': 'Murugan Idli Shop',
#     'url': 'https://www.zomato.com/chennai/murugan-idli-shop-t-nagar?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '77-1/A, G.N. Chetty Road, T. Nagar, Chennai',
#      'locality': 'T. Nagar',
#      'city': 'Chennai',
#      'city_id': 7,
#      'latitude': '13.0425163415',
#      'longitude': '80.2353278920',
#      'zipcode': '0',
#      'country_id': 1,
#      'locality_verbose': 'T. Nagar, Chennai'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '7 AM to 9 PM',
#     'average_cost_for_two': 200,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Cash',
#      'Takeaway Available',
#      'Credit Card',
#      'Debit Card',
#      'Lunch',
#      'Delivery',
#      'Breakfast',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Digital Payments Accepted',
#      'Catering Available',
#      'Pure Veg'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/1/65381/453d6d02b3a9a2b6470d655045edef35.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.2',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.2'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 8341},
#     'all_reviews_count': 602,
#     'photos_url': 'https://www.zomato.com/chennai/murugan-idli-shop-t-nagar/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 356,
#     'menu_url': 'https://www.zomato.com/chennai/murugan-idli-shop-t-nagar/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/1/65381/453d6d02b3a9a2b6470d655045edef35.jpg?output-format=webp',
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/65381',
#     'order_url': 'https://www.zomato.com/chennai/murugan-idli-shop-t-nagar/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/chennai/murugan-idli-shop-t-nagar/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '044 42025076, +91 9597086501',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 1, 'takeaway': -1},
#      'res_id': 65384,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '65384',
#     'name': 'Murugan Idli Shop',
#     'url': 'https://www.zomato.com/chennai/murugan-idli-shop-besant-nagar?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '149/1, 6th Avenue, Opposite Vilankanni Church, Besant Nagar, Chennai',
#      'locality': 'Besant Nagar',
#      'city': 'Chennai',
#      'city_id': 7,
#      'latitude': '12.9954792249',
#      'longitude': '80.2701758221',
#      'zipcode': '0',
#      'country_id': 1,
#      'locality_verbose': 'Besant Nagar, Chennai'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '7 AM to 9 PM',
#     'average_cost_for_two': 200,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Lunch',
#      'Cash',
#      'Takeaway Available',
#      'Credit Card',
#      'Debit Card',
#      'Dinner',
#      'Delivery',
#      'Breakfast',
#      'Free Parking',
#      'Indoor Seating',
#      'Pure Veg'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/1/65381/453d6d02b3a9a2b6470d655045edef35.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.1',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.1'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 6442},
#     'all_reviews_count': 803,
#     'photos_url': 'https://www.zomato.com/chennai/murugan-idli-shop-besant-nagar/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 467,
#     'menu_url': 'https://www.zomato.com/chennai/murugan-idli-shop-besant-nagar/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/1/65381/453d6d02b3a9a2b6470d655045edef35.jpg',
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/65384',
#     'order_url': 'https://www.zomato.com/chennai/murugan-idli-shop-besant-nagar/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/chennai/murugan-idli-shop-besant-nagar/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '044 42018181, +91 9597086503',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 0, 'takeaway': -1},
#      'res_id': 71664,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '71664',
#     'name': 'Dakshin - Crowne Plaza Chennai Adyar Park',
#     'url': 'https://www.zomato.com/chennai/dakshin-crowne-plaza-chennai-adyar-park-alwarpet?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'NO.132 T T K ROAD CHENNAI ,Chennai(Tamil Nadu), -600018',
#      'locality': 'Crowne Plaza Chennai Adyar Park, Alwarpet',
#      'city': 'Chennai',
#      'city_id': 7,
#      'latitude': '13.0291922156',
#      'longitude': '80.2495757863',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Crowne Plaza Chennai Adyar Park, Alwarpet, Chennai'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian, Kerala, Andhra',
#     'timings': '12noon – 3pm, 7pm – 11pm (Mon-Sun)',
#     'average_cost_for_two': 2500,
#     'price_range': 4,
#     'currency': 'Rs.',
#     'highlights': ['Cash',
#      'Serves Alcohol',
#      'Debit Card',
#      'Credit Card',
#      'Lunch',
#      'Dinner',
#      'Luxury Dining',
#      'Fullbar',
#      'Indoor Seating',
#      'Wheelchair Accessible',
#      'Gourmet',
#      'Air Conditioned',
#      '4/5 Star',
#      'Wifi',
#      'Table booking recommended'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/71664_RESTAURANT_c40af969415d57b8b5737f440944e885_c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.5',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'rating_obj': {'title': {'text': '4.5'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 384},
#     'all_reviews_count': 234,
#     'photos_url': 'https://www.zomato.com/chennai/dakshin-crowne-plaza-chennai-adyar-park-alwarpet/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 556,
#     'menu_url': 'https://www.zomato.com/chennai/dakshin-crowne-plaza-chennai-adyar-park-alwarpet/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/71664_RESTAURANT_c40af969415d57b8b5737f440944e885_c.jpg',
#     'medio_provider': 1,
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/71664',
#     'is_table_reservation_supported': 1,
#     'has_table_booking': 1,
#     'book_url': 'https://www.zomato.com/chennai/dakshin-crowne-plaza-chennai-adyar-park-alwarpet/book?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'events_url': 'https://www.zomato.com/chennai/dakshin-crowne-plaza-chennai-adyar-park-alwarpet/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '044 42991830, 044 24994101',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Fine Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 1, 'takeaway': -1},
#      'res_id': 65789,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '65789',
#     'name': 'Mylai Karpagambal Mess',
#     'url': 'https://www.zomato.com/chennai/mylai-karpagambal-mess-mylapore?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '20, East Mada Street, Mylapore, Chennai',
#      'locality': 'Mylapore',
#      'city': 'Chennai',
#      'city_id': 7,
#      'latitude': '13.0326539704',
#      'longitude': '80.2710488811',
#      'zipcode': '0',
#      'country_id': 1,
#      'locality_verbose': 'Mylapore, Chennai'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '7am – 10pm (Mon-Sun)',
#     'average_cost_for_two': 200,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'Breakfast',
#      'Dinner',
#      'Cash',
#      'Takeaway Available',
#      'Credit Card',
#      'Debit Card',
#      'Lunch',
#      'Pure Veg',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/65789_RESTAURANT_b1af2b2cfe1c5b03c57a64eb6a752081.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.1',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.1'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 856},
#     'all_reviews_count': 355,
#     'photos_url': 'https://www.zomato.com/chennai/mylai-karpagambal-mess-mylapore/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 238,
#     'menu_url': 'https://www.zomato.com/chennai/mylai-karpagambal-mess-mylapore/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/65789_RESTAURANT_b1af2b2cfe1c5b03c57a64eb6a752081.jpg',
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/65789',
#     'order_url': 'https://www.zomato.com/chennai/mylai-karpagambal-mess-mylapore/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/chennai/mylai-karpagambal-mess-mylapore/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '044 42112377',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Mess'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 65690,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '65690',
#     'name': 'Southern Spice - Taj Coromandel',
#     'url': 'https://www.zomato.com/chennai/southern-spice-taj-coromandel-nungambakkam?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Taj Coromandel, 37, Mahatma Gandhi Road, Nungambakkam, Chennai',
#      'locality': 'Taj Coromandel, Nungambakkam',
#      'city': 'Chennai',
#      'city_id': 7,
#      'latitude': '13.0585871724',
#      'longitude': '80.2473793924',
#      'zipcode': '600034',
#      'country_id': 1,
#      'locality_verbose': 'Taj Coromandel, Nungambakkam, Chennai'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '12:30 PM to 2:45 PM, 7 PM to 11:45 PM',
#     'average_cost_for_two': 3000,
#     'price_range': 4,
#     'currency': 'Rs.',
#     'highlights': ['Lunch',
#      'Cash',
#      'Credit Card',
#      'Dinner',
#      'Debit Card',
#      'Wheelchair Accessible',
#      '4/5 Star',
#      'Indoor Seating',
#      'Luxury Dining',
#      'Fullbar',
#      'Table booking recommended',
#      'Valet Parking Available'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'SHAWMAN',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/65690_RESTAURANT_64932ced475c0537affea6917b1d6767_c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.7',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'rating_obj': {'title': {'text': '4.7'},
#       'bg_color': {'type': 'lime', 'tint': '800'}},
#      'votes': 433},
#     'all_reviews_count': 205,
#     'photos_url': 'https://www.zomato.com/chennai/southern-spice-taj-coromandel-nungambakkam/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 437,
#     'menu_url': 'https://www.zomato.com/chennai/southern-spice-taj-coromandel-nungambakkam/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/65690_RESTAURANT_64932ced475c0537affea6917b1d6767_c.jpg?output-format=webp',
#     'medio_provider': '',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/65690',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 1,
#     'book_url': 'https://www.zomato.com/chennai/southern-spice-taj-coromandel-nungambakkam/book?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'events_url': 'https://www.zomato.com/chennai/southern-spice-taj-coromandel-nungambakkam/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '044 66002827',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Fine Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 1, 'takeaway': -1},
#      'res_id': 18585882,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '18585882',
#     'name': 'Idlies',
#     'url': 'https://www.zomato.com/chennai/idlies-ashok-nagar?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '17, 18th Avenue, Ashok Nagar, Chennai',
#      'locality': 'Ashok Nagar',
#      'city': 'Chennai',
#      'city_id': 7,
#      'latitude': '13.0401420787',
#      'longitude': '80.2108956501',
#      'zipcode': '600078',
#      'country_id': 1,
#      'locality_verbose': 'Ashok Nagar, Chennai'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '7 AM to 3 PM, 5 PM to 9:30 PM',
#     'average_cost_for_two': 250,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Delivery',
#      'Credit Card',
#      'Debit Card',
#      'Lunch',
#      'Cash',
#      'Takeaway Available',
#      'Breakfast',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Digital Payments Accepted'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/chains/7/18361817/af6e4341245a9e632f26e4925423d5df.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.0',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.0'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 1764},
#     'all_reviews_count': 183,
#     'photos_url': 'https://www.zomato.com/chennai/idlies-ashok-nagar/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 221,
#     'menu_url': 'https://www.zomato.com/chennai/idlies-ashok-nagar/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/7/18361817/af6e4341245a9e632f26e4925423d5df.jpg?output-format=webp',
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18585882',
#     'order_url': 'https://www.zomato.com/chennai/idlies-ashok-nagar/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/chennai/idlies-ashok-nagar/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9384961006',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 0, 'takeaway': -1},
#      'res_id': 19233043,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '19233043',
#     'name': 'Aadhirai',
#     'url': 'https://www.zomato.com/chennai/aadhirai-nungambakkam?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '31, Jambulingam Street, Off Valluvar Kottam High Road, Nungambakkam, Chennai',
#      'locality': 'Nungambakkam',
#      'city': 'Chennai',
#      'city_id': 7,
#      'latitude': '13.0582938803',
#      'longitude': '80.2419392020',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Nungambakkam, Chennai'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian, Beverages',
#     'timings': '12 Noon to 9 PM',
#     'average_cost_for_two': 1000,
#     'price_range': 3,
#     'currency': 'Rs.',
#     'highlights': ['Credit Card',
#      'Dinner',
#      'Cash',
#      'Debit Card',
#      'Lunch',
#      'Takeaway Available',
#      'Indoor Seating',
#      'Air Conditioned'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/chains/3/19233043/8ab4c754d3c9e87f16333eb23bf1c883.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.1',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.1'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 325},
#     'all_reviews_count': 243,
#     'photos_url': 'https://www.zomato.com/chennai/aadhirai-nungambakkam/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 202,
#     'menu_url': 'https://www.zomato.com/chennai/aadhirai-nungambakkam/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/3/19233043/8ab4c754d3c9e87f16333eb23bf1c883.jpg',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/19233043',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/chennai/aadhirai-nungambakkam/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 8939358485, +91 9994016415',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 1, 'takeaway': -1},
#      'res_id': 18745112,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '18745112',
#     'name': 'Shree Konar Vilas',
#     'url': 'https://www.zomato.com/chennai/shree-konar-vilas-purasavakkam?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '128, Perambur Barracks Road, Purasavakkam, Chennai',
#      'locality': 'Purasavakkam',
#      'city': 'Chennai',
#      'city_id': 7,
#      'latitude': '13.0898351571',
#      'longitude': '80.2586547285',
#      'zipcode': '629007',
#      'country_id': 1,
#      'locality_verbose': 'Purasavakkam, Chennai'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian, Chettinad',
#     'timings': '11:30am – 11am (Mon-Sun)',
#     'average_cost_for_two': 500,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Takeaway Available',
#      'Lunch',
#      'Credit Card',
#      'Cash',
#      'Dinner',
#      'Delivery',
#      'Debit Card',
#      'Air Conditioned',
#      'Indoor Seating',
#      'Digital Payments Accepted'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/2/19150652/135be9bd6a9ca889ebf592fa57fb6cd7.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.0',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.0'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 4234},
#     'all_reviews_count': 96,
#     'photos_url': 'https://www.zomato.com/chennai/shree-konar-vilas-purasavakkam/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 160,
#     'menu_url': 'https://www.zomato.com/chennai/shree-konar-vilas-purasavakkam/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/2/19150652/135be9bd6a9ca889ebf592fa57fb6cd7.jpg',
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18745112',
#     'order_url': 'https://www.zomato.com/chennai/shree-konar-vilas-purasavakkam/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/chennai/shree-konar-vilas-purasavakkam/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 8939280000, +91 9080999216, 00 04448596480',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 71679,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '71679',
#     'name': 'National Lodge',
#     'url': 'https://www.zomato.com/chennai/national-lodge-sowcarpet?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '112, Govindappa Naickan Street, Sowcarpet, Chennai',
#      'locality': 'Sowcarpet',
#      'city': 'Chennai',
#      'city_id': 7,
#      'latitude': '13.0898877340',
#      'longitude': '80.2815487236',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Sowcarpet, Chennai'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Andhra, South Indian',
#     'timings': '11 AM to 3:30 PM, 7 PM to 10 PM (Mon-Sat), 11 AM to 4 PM (Sun)',
#     'average_cost_for_two': 300,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Cash',
#      'Takeaway Available',
#      'Lunch',
#      'Delivery',
#      'Indoor Seating',
#      'Air Conditioned'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/reviews_photos/081/6ed1609b97a184fcf604c126e724a081_1476178734.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.0',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.0'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 1210},
#     'all_reviews_count': 85,
#     'photos_url': 'https://www.zomato.com/chennai/national-lodge-sowcarpet/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 26,
#     'menu_url': 'https://www.zomato.com/chennai/national-lodge-sowcarpet/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/reviews_photos/081/6ed1609b97a184fcf604c126e724a081_1476178734.jpg?output-format=webp',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/71679',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/chennai/national-lodge-sowcarpet/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '044 25369508',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 1, 'takeaway': -1},
#      'res_id': 18737581,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '18737581',
#     'name': 'Kumbakkarai',
#     'url': 'https://www.zomato.com/chennai/kumbakkarai-nungambakkam?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '40/156, Kodambakkam High Road, Nungambakkam, Chennai',
#      'locality': 'Nungambakkam',
#      'city': 'Chennai',
#      'city_id': 7,
#      'latitude': '13.0531256110',
#      'longitude': '80.2470226586',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Nungambakkam, Chennai'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian, Chettinad',
#     'timings': 'Mon-Sun (11 AM to 11:30 PM)',
#     'average_cost_for_two': 850,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Lunch',
#      'Cash',
#      'Takeaway Available',
#      'Debit Card',
#      'Dinner',
#      'Delivery',
#      'Credit Card',
#      'Free Parking',
#      'Table booking for Groups',
#      'Indoor Seating',
#      'Air Conditioned'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/1/18737581/a5d97221e96b6db3f2f15df425481861.jpeg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.1',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.1'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 704},
#     'all_reviews_count': 103,
#     'photos_url': 'https://www.zomato.com/chennai/kumbakkarai-nungambakkam/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 120,
#     'menu_url': 'https://www.zomato.com/chennai/kumbakkarai-nungambakkam/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/1/18737581/a5d97221e96b6db3f2f15df425481861.jpeg',
#     'medio_provider': 1,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18737581',
#     'order_url': 'https://www.zomato.com/chennai/kumbakkarai-nungambakkam/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 1,
#     'has_table_booking': 1,
#     'book_url': 'https://www.zomato.com/chennai/kumbakkarai-nungambakkam/book?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'events_url': 'https://www.zomato.com/chennai/kumbakkarai-nungambakkam/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9884363273, +91 9003125659',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 1, 'takeaway': -1},
#      'res_id': 73302,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '73302',
#     'name': 'Murugan Idli Shop',
#     'url': 'https://www.zomato.com/chennai/murugan-idli-shop-velachery?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '129/28, 100 Feet Road, Velachery, Chennai',
#      'locality': 'Velachery',
#      'city': 'Chennai',
#      'city_id': 7,
#      'latitude': '12.9787031796',
#      'longitude': '80.2193570137',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Velachery, Chennai'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '7 AM to 9 PM',
#     'average_cost_for_two': 200,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Lunch',
#      'Takeaway Available',
#      'No Alcohol Available',
#      'Delivery',
#      'Cash',
#      'Credit Card',
#      'Dinner',
#      'Debit Card',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Table booking recommended',
#      'Pure Veg'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/1/65381/453d6d02b3a9a2b6470d655045edef35.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.1',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.1'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 10884},
#     'all_reviews_count': 335,
#     'photos_url': 'https://www.zomato.com/chennai/murugan-idli-shop-velachery/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 128,
#     'menu_url': 'https://www.zomato.com/chennai/murugan-idli-shop-velachery/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/1/65381/453d6d02b3a9a2b6470d655045edef35.jpg?output-format=webp',
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/73302',
#     'order_url': 'https://www.zomato.com/chennai/murugan-idli-shop-velachery/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/chennai/murugan-idli-shop-velachery/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9597080607',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 68543,
#      'is_grocery_store': False},
#     'apikey': '7c5b4cda151a68ab847143b592e4c232',
#     'id': '68543',
#     'name': 'Kozhi Idli',
#     'url': 'https://www.zomato.com/chennai/kozhi-idli-gopalapuram?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '155, Avvai Shanmugam Salai, Near AIADMK Party Office, Gopalapuram, Chennai',
#      'locality': 'Gopalapuram',
#      'city': 'Chennai',
#      'city_id': 7,
#      'latitude': '13.0473601720',
#      'longitude': '80.2653377876',
#      'zipcode': '600014',
#      'country_id': 1,
#      'locality_verbose': 'Gopalapuram, Chennai'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian',
#     'timings': '12:30 PM – 3 PM, 6 PM – 11:30 PM (Mon-Sat), 6 PM – 11:30 PM (Sun)',
#     'average_cost_for_two': 300,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Lunch',
#      'Dinner',
#      'Takeaway Available',
#      'Delivery',
#      'Cash',
#      'Air Conditioned',
#      'Free Parking',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/chains/3/68543/dd5ce37aa0f4d0c0842bc334aba2c240.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.1',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.1'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 611},
#     'all_reviews_count': 157,
#     'photos_url': 'https://www.zomato.com/chennai/kozhi-idli-gopalapuram/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 126,
#     'menu_url': 'https://www.zomato.com/chennai/kozhi-idli-gopalapuram/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/3/68543/dd5ce37aa0f4d0c0842bc334aba2c240.jpg',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/68543',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/chennai/kozhi-idli-gopalapuram/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9094778000',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}}]}

# %%
budget = 'budg'

# %%
d = json.loads(r)
res_list = d['restaurants']
res_frame = pd.DataFrame([{'name': x['restaurant']['name'], 'rating': x['restaurant']['user_rating']['aggregate_rating'],
'address': x['restaurant']['location']['address'],'cost_for_2': x['restaurant']['average_cost_for_two']} for x in res_list])
res_frame.sort_values(by = 'rating', ascending = False,inplace = True)

# %%
if budget == 'budg':
    final_frame = res_frame.loc[(res_frame.cost_for_2 <= 300)][:10].reset_index()
elif budget == 'norml':
    final_frame = res_frame.loc[(res_frame.cost_for_2 > 300) & (res_frame.cost_for_2 <= 700)][:10].reset_index()
elif budget == 'expnsv':
    final_frame = res_frame.loc[(res_frame.cost_for_2 > 700)][:10].reset_index()
else:
    final_frame = res_frame[:10]

# %%
email_response = 'Below are the top restaurants for your search: \n'
chat_response = ''
for i in range(len(final_frame)):
    j = i
    email_response += str(j+1) + ". " + final_frame.loc[i,'name'] + " with average rating of " + str(final_frame.loc[i,'rating']) + " found at " \
    + final_frame.loc[i,'address'] + " and the average cost for 2 would be INR " + str(final_frame.loc[i,'cost_for_2']) + ". \n"
if len(final_frame) <5:
    chat_response = 'Got ' + str(len(final_frame)) + ' restaurants that matched your criteria. Try with a higher budget if needed. \n' \
                    + email_response
elif len(final_frame) == 5:
    chat_response = email_response
elif len(final_frame) > 5:
    for i in range(5):
        j = i
        chat_response += 'Below are the top restaurants for your search: \n' + str(j+1) + ". " + final_frame.loc[i,'name'] + \
        " with average rating of " + str(final_frame.loc[i,'rating']) + " found at " \
        + final_frame.loc[i,'address'] + " and the average cost for 2 would be INR " + str(final_frame.loc[i,'cost_for_2']) + ". \n"

# %%
email_response
# Out:
# "Below are the top restaurants for your search: \n1. Andhikkadai with average rating of 4.4 found at 20, Dhandeeswaram Main Road, Velachery, Chennai and the average cost for 2 would be INR 200. \n2. Eating Circles with average rating of 4.4 found at 6, CP Ramaswamy Road, Alwarpet, Chennai and the average cost for 2 would be INR 250. \n3. Rayar's Mess with average rating of 4.4 found at 31, Arundale Street, Mylapore, Chennai and the average cost for 2 would be INR 100. \n4. Murugan Idli Shop with average rating of 4.2 found at 77-1/A, G.N. Chetty Road, T. Nagar, Chennai and the average cost for 2 would be INR 200. \n5. Murugan Idli Shop with average rating of 4.1 found at 129/28, 100 Feet Road, Velachery, Chennai and the average cost for 2 would be INR 200. \n6. Mylai Karpagambal Mess with average rating of 4.1 found at 20, East Mada Street, Mylapore, Chennai and the average cost for 2 would be INR 200. \n7. Murugan Idli Shop with average rating of 4.1 found at 149/1, 6th Avenue, Opposite Vilankanni Church, Besant Nagar, Chennai and the average cost for 2 would be INR 200. \n8. Kozhi Idli with average rating of 4.1 found at 155, Avvai Shanmugam Salai, Near AIADMK Party Office, Gopalapuram, Chennai and the average cost for 2 would be INR 300. \n9. Idlies with average rating of 4.0 found at 17, 18th Avenue, Ashok Nagar, Chennai and the average cost for 2 would be INR 250. \n10. National Lodge with average rating of 4.0 found at 112, Govindappa Naickan Street, Sowcarpet, Chennai and the average cost for 2 would be INR 300. \n"

# %%
chat_response
# Out:
# "1. Andhikkadai with average rating of 4.4 found at 20, Dhandeeswaram Main Road, Velachery, Chennai and the average cost for 2 would be INR 200. \n2. Eating Circles with average rating of 4.4 found at 6, CP Ramaswamy Road, Alwarpet, Chennai and the average cost for 2 would be INR 250. \n3. Rayar's Mess with average rating of 4.4 found at 31, Arundale Street, Mylapore, Chennai and the average cost for 2 would be INR 100. \n4. Murugan Idli Shop with average rating of 4.2 found at 77-1/A, G.N. Chetty Road, T. Nagar, Chennai and the average cost for 2 would be INR 200. \n5. Murugan Idli Shop with average rating of 4.1 found at 129/28, 100 Feet Road, Velachery, Chennai and the average cost for 2 would be INR 200. \n"

# %%
final_frame
# Out:
#    index                 name rating  \
# 0     19      Ovenstory Pizza    4.0
# 1      6               Kalo's    4.0
# 2     17          Pizza Dough    3.8
# 3      8     Midnight Madness    3.7
# 4     10  The Shack @ Elliots    3.5
#
#                                              address  cost_for_2
# 0  No. 19/8, Pushpa Nagar Main Road, Nungambakkam...         400
# 1  Shop 8, Thiruvalluvar Nagar, Besant Nagar, Che...         500
# 2  114, Ground Floor, Bazaar Road, Sadhasivam Nag...         600
# 3  1/1, F-3, 1st Floor, Sindhuja Complex, 29th Cr...         450
# 4  71, Odaikuppam, Near Ashtalakshmi Temple, Besa...         700

# %%
res_frame.loc[(res_frame.cost_for_2 <= 300)][:10]
# Out:
#                       name rating  \
# 3              Andhikkadai    4.4
# 1           Eating Circles    4.4
# 2             Rayar's Mess    4.4
# 8        Murugan Idli Shop    4.2
# 18       Murugan Idli Shop    4.1
# 11  Mylai Karpagambal Mess    4.1
# 9        Murugan Idli Shop    4.1
# 19              Kozhi Idli    4.1
# 13                  Idlies    4.0
# 16          National Lodge    4.0
#
#                                               address  cost_for_2
# 3     20, Dhandeeswaram Main Road, Velachery, Chennai         200
# 1             6, CP Ramaswamy Road, Alwarpet, Chennai         250
# 2              31, Arundale Street, Mylapore, Chennai         100
# 8         77-1/A, G.N. Chetty Road, T. Nagar, Chennai         200
# 18          129/28, 100 Feet Road, Velachery, Chennai         200
# 11            20, East Mada Street, Mylapore, Chennai         200
# 9   149/1, 6th Avenue, Opposite Vilankanni Church,...         200
# 19  155, Avvai Shanmugam Salai, Near AIADMK Party ...         300
# 13              17, 18th Avenue, Ashok Nagar, Chennai         250
# 16  112, Govindappa Naickan Street, Sowcarpet, Che...         300

# %%
res_frame.loc[(res_frame.cost_for_2 > 700)][:10]
# Out:
#                                          name rating  \
# 12            Southern Spice - Taj Coromandel    4.7
# 10  Dakshin - Crowne Plaza Chennai Adyar Park    4.5
# 7                                  Savya Rasa    4.4
# 14                                   Aadhirai    4.1
# 17                                Kumbakkarai    4.1
#
#                                               address  cost_for_2
# 12  Taj Coromandel, 37, Mahatma Gandhi Road, Nunga...        3000
# 10  NO.132 T T K ROAD CHENNAI ,Chennai(Tamil Nadu)...        2500
# 7    2/10, Gandhi Mandapam Road, Kotturpuram, Chennai        1600
# 14  31, Jambulingam Street, Off Valluvar Kottam Hi...        1000
# 17  40/156, Kodambakkam High Road, Nungambakkam, C...         850

# %%
res_frame[:50]
# Out:
#                                          name rating  \
# 12            Southern Spice - Taj Coromandel    4.7
# 0                       Prems Graama Bhojanam    4.6
# 10  Dakshin - Crowne Plaza Chennai Adyar Park    4.5
# 3                                 Andhikkadai    4.4
# 6                            That Mallu Joint    4.4
# 7                                  Savya Rasa    4.4
# 1                              Eating Circles    4.4
# 2                                Rayar's Mess    4.4
# 8                           Murugan Idli Shop    4.2
# 4                         Nellai Vairamaligai    4.2
# 14                                   Aadhirai    4.1
# 18                          Murugan Idli Shop    4.1
# 17                                Kumbakkarai    4.1
# 11                     Mylai Karpagambal Mess    4.1
# 9                           Murugan Idli Shop    4.1
# 5                                 Mana Andhra    4.1
# 19                                 Kozhi Idli    4.1
# 13                                     Idlies    4.0
# 15                          Shree Konar Vilas    4.0
# 16                             National Lodge    4.0
#
#                                               address  cost_for_2
# 12  Taj Coromandel, 37, Mahatma Gandhi Road, Nunga...        3000
# 0   23/10, 3rd Main Road, Kasturba Nagar, Adyar, C...         500
# 10  NO.132 T T K ROAD CHENNAI ,Chennai(Tamil Nadu)...        2500
# 3     20, Dhandeeswaram Main Road, Velachery, Chennai         200
# 6   2nd Floor, PMG Complex, GN Chetty Road, T. Nag...         600
# 7    2/10, Gandhi Mandapam Road, Kotturpuram, Chennai        1600
# 1             6, CP Ramaswamy Road, Alwarpet, Chennai         250
# 2              31, Arundale Street, Mylapore, Chennai         100
# 8         77-1/A, G.N. Chetty Road, T. Nagar, Chennai         200
# 4   60, Thirumalai Pillai Road, Rama Kamath Puram,...         500
# 14  31, Jambulingam Street, Off Valluvar Kottam Hi...        1000
# 18          129/28, 100 Feet Road, Velachery, Chennai         200
# 17  40/156, Kodambakkam High Road, Nungambakkam, C...         850
# 11            20, East Mada Street, Mylapore, Chennai         200
# 9   149/1, 6th Avenue, Opposite Vilankanni Church,...         200
# 5   18/24, Khader Nawaskhan Road, Nungambakkam, Ch...         600
# 19  155, Avvai Shanmugam Salai, Near AIADMK Party ...         300
# 13              17, 18th Avenue, Ashok Nagar, Chennai         250
# 15  128, Perambur Barracks Road, Purasavakkam, Che...         500
# 16  112, Govindappa Naickan Street, Sowcarpet, Che...         300

# %%
df2 = df1.sort_values(by = 'rating', ascending = False)

# %%
abc = ''
for x in df2:
    response = df2['name'] + " with average rating of " + df2['rating'] + " found at " \
    + df2['address'] + " and the average cost for 2 would be INR " + df2['cost_for_2'] + ". \n"
for a in response:
    abc += str(a)

# %%
response = ''
for i in range(len(df1)):
    j = i
    response += str(j+1) + ". " + df1.loc[i,'name'] + " with average rating of " + str(df1.loc[i,'rating']) + " found at " \
    + df1.loc[i,'address'] + " and the average cost for 2 would be INR " + str(df1.loc[i,'cost_for_2']) + ". \n"

# %%
response
# Out:
# "1. Pedreno's with average rating of 4.1 found at 113/114, PS Sivaswami Salai, Mylapore, Chennai and the average cost for 2 would be INR 1200. \n2. Joker's Kitchen with average rating of 4.3 found at 94/1, Door 211/1, TTK Road, Near Ethiraj Kalayana Mandapam, Alwarpet, Chennai and the average cost for 2 would be INR 800. \n3. Asvah 24 with average rating of 4.2 found at 24 Beach Road, Sri Kapaleeshwar Nagar, Neelangarai, Chennai and the average cost for 2 would be INR 1700. \n4. Tuscana Pizzeria with average rating of 4.1 found at 19, 3rd Street, Wallace Garden Road, Nungambakkam, Chennai and the average cost for 2 would be INR 1200. \n5. Tryst Cafe with average rating of 4.1 found at 4/359, Gatsby Village, East Coast Road, Neelangarai, Chennai and the average cost for 2 would be INR 800. \n6. Jonah's Bistro with average rating of 4.2 found at G-12, Phoenix Mall, O 66/N 142, Velachery Road, Velachery, Chennai and the average cost for 2 would be INR 800. \n7. Kalo's with average rating of 4.0 found at Shop 8, Thiruvalluvar Nagar, Besant Nagar, Chennai and the average cost for 2 would be INR 500. \n8. Upper Deck - Taj Fisherman's Cove Resort & Spa with average rating of 4.3 found at Vivanta by Taj  Fisherman's Cove, Covelong Beach, Off East Coast Road (ECR), Kovalam, Chennai and the average cost for 2 would be INR 3500. \n9. Midnight Madness with average rating of 3.7 found at 1/1, F-3, 1st Floor, Sindhuja Complex, 29th Cross Street, Indira Nagar, Adyar, Chennai and the average cost for 2 would be INR 450. \n10. Ox & Tomato with average rating of 4.0 found at 2/15, Ganapathy Colony, Main Road, Near Bank of Baroda ATM, Sri Ram Nagar, Teynampet, Chennai and the average cost for 2 would be INR 850. \n"

# %%
type(str(df2['name']))
# Out:
# str

# %%
abc
# Out:
# "Joker's Kitchen with average rating of 4.3 found at 94/1, Door 211/1, TTK Road, Near Ethiraj Kalayana Mandapam, Alwarpet, Chennai and the average cost for 2 would be INR 1     800\n7    3500\n2    1700\n5     800\n0    1200\n3    1200\n4     800\n6     500\n9     850\n8     450\nName: cost_for_2, dtype: int64. \nUpper Deck - Taj Fisherman's Cove Resort & Spa with average rating of 4.3 found at Vivanta by Taj  Fisherman's Cove, Covelong Beach, Off East Coast Road (ECR), Kovalam, Chennai and the average cost for 2 would be INR 1     800\n7    3500\n2    1700\n5     800\n0    1200\n3    1200\n4     800\n6     500\n9     850\n8     450\nName: cost_for_2, dtype: int64. \nAsvah 24 with average rating of 4.2 found at 24 Beach Road, Sri Kapaleeshwar Nagar, Neelangarai, Chennai and the average cost for 2 would be INR 1     800\n7    3500\n2    1700\n5     800\n0    1200\n3    1200\n4     800\n6     500\n9     850\n8     450\nName: cost_for_2, dtype: int64. \nJonah's Bistro with average rating of 4.2 found at G-12, Phoenix Mall, O 66/N 142, Velachery Road, Velachery, Chennai and the average cost for 2 would be INR 1     800\n7    3500\n2    1700\n5     800\n0    1200\n3    1200\n4     800\n6     500\n9     850\n8     450\nName: cost_for_2, dtype: int64. \nPedreno's with average rating of 4.1 found at 113/114, PS Sivaswami Salai, Mylapore, Chennai and the average cost for 2 would be INR 1     800\n7    3500\n2    1700\n5     800\n0    1200\n3    1200\n4     800\n6     500\n9     850\n8     450\nName: cost_for_2, dtype: int64. \nTuscana Pizzeria with average rating of 4.1 found at 19, 3rd Street, Wallace Garden Road, Nungambakkam, Chennai and the average cost for 2 would be INR 1     800\n7    3500\n2    1700\n5     800\n0    1200\n3    1200\n4     800\n6     500\n9     850\n8     450\nName: cost_for_2, dtype: int64. \nTryst Cafe with average rating of 4.1 found at 4/359, Gatsby Village, East Coast Road, Neelangarai, Chennai and the average cost for 2 would be INR 1     800\n7    3500\n2    1700\n5     800\n0    1200\n3    1200\n4     800\n6     500\n9     850\n8     450\nName: cost_for_2, dtype: int64. \nKalo's with average rating of 4.0 found at Shop 8, Thiruvalluvar Nagar, Besant Nagar, Chennai and the average cost for 2 would be INR 1     800\n7    3500\n2    1700\n5     800\n0    1200\n3    1200\n4     800\n6     500\n9     850\n8     450\nName: cost_for_2, dtype: int64. \nOx & Tomato with average rating of 4.0 found at 2/15, Ganapathy Colony, Main Road, Near Bank of Baroda ATM, Sri Ram Nagar, Teynampet, Chennai and the average cost for 2 would be INR 1     800\n7    3500\n2    1700\n5     800\n0    1200\n3    1200\n4     800\n6     500\n9     850\n8     450\nName: cost_for_2, dtype: int64. \nMidnight Madness with average rating of 3.7 found at 1/1, F-3, 1st Floor, Sindhuja Complex, 29th Cross Street, Indira Nagar, Adyar, Chennai and the average cost for 2 would be INR 1     800\n7    3500\n2    1700\n5     800\n0    1200\n3    1200\n4     800\n6     500\n9     850\n8     450\nName: cost_for_2, dtype: int64. \n"

# %%
s = 'aaalkjsdf;ljsD;lgfj;lSDJFGL:jdf;lgjl;dfjgl;dJgl;jdfl;gjdfl;gjl;dfjg;ldfjgl;jdgjdf;ljgl;DFJgl;jd;lgjdfl;gjl;dfjgl;dfjgl;jdfl;gjdfl;gjl;dzfjgl;dfjg;jkdf;gjdf;ljg;dfjg;dfj;'

# %%
s
# Out:
# 'aaalkjsdf;ljsD;lgfj;lSDJFGL:jdf;lgjl;dfjgl;dJgl;jdfl;gjdfl;gjl;dfjg;ldfjgl;jdgjdf;ljgl;DFJgl;jd;lgjdfl;gjl;dfjgl;dfjgl;jdfl;gjdfl;gjl;dzfjgl;dfjg;jkdf;gjdf;ljg;dfjg;dfj;'

# %%
city = ['Ahmedabad', 'Bengaluru', 'Bangalore', 'Chennai', 'Madras', 'Delhi', 'New Delhi', 'Hyderabad', 'Kolkata', 'Calcutta', 'Mumbai', 'Bombay', 'Pune',
					'Agra', 'Ajmer', 'Aligarh', 'Amravati', 'Amritsar', 'Asansol', 'Aurangabad', 'Bareilly', 'Belgaum', 'Bhavnagar', 'Bhiwandi', 'Bhopal', 'Bhubaneswar', 
					'Bikaner', 'Bilaspur', 'Bokaro Steel City', 'Chandigarh', 'Coimbatore', 'Cuttack', 'Dehradun', 'Dhanbad', 'Bhilai', 'Durgapur', 'Dindigul', 'Erode', 
					'Faridabad', 'Firozabad', 'Ghaziabad', 'Gorakhpur', 'Gulbarga', 'Guntur', 'Gwalior', 'Gurgaon', 'Guwahati', 'Hamirpur', 'Hubli–Dharwad', 'Indore', 
					'Jabalpur', 'Jaipur', 'Jalandhar', 'Jammu', 'Jamnagar', 'Jamshedpur', 'Jhansi', 'Jodhpur', 'Kakinada', 'Kannur', 'Kanpur', 'Karnal', 'Kochi', 
					'Kolhapur', 'Kollam', 'Kozhikode', 'Kurnool', 'Ludhiana', 'Lucknow', 'Madurai', 'Malappuram', 'Mathura', 'Mangalore', 'Meerut', 'Moradabad', 
					'Mysore', 'Nagpur', 'Nanded', 'Nashik', 'Nellore', 'Noida', 'Patna', 'Pondicherry', 'Purulia', 'Prayagraj', 'Raipur', 'Rajkot', 'Rajahmundry', 
					'Ranchi', 'Rourkela', 'Salem', 'Sangli', 'Shimla', 'Siliguri', 'Solapur', 'Srinagar', 'Surat', 'Thanjavur', 'Thiruvananthapuram', 'Thrissur', 
					'Tiruchirappalli', 'Tirunelveli', 'Ujjain', 'Bijapur', 'Vadodara', 'Varanasi', 'Vasai-Virar City', 'Vijayawada', 'Visakhapatnam', 'Vellore', 'Warangal']

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# %%
from_email = 'foodie.restaurantfinder@gmail.com'
to_email = 'sundararajan.n@gmail.com'
cred = 'Upgrad123'
gmail = smtplib.SMTP('smtp.gmail.com',587)
gmail.ehlo()
gmail.starttls()
gmail.login(from_email, cred)
email_subject = 'Hello from Foodie'
email_msg = MIMEMultipart()
email_msg['From'] = from_email
email_msg['TO'] = to_email
email_msg['Subject'] = email_subject
email_body = response
email_msg.attach(MIMEText(email_body,'plain'))
email_text = email_msg.as_string()
gmail.sendmail(from_email,to_email,email_text)
gmail.close()

# %%
import spacy
nlp = spacy.load('en_core_web_md')
# Out:
# less 7

# %%
test = nlp('find a less than 300 restaurant')
print(test[1].text, test[2].idx)
# Out:
# a 7
